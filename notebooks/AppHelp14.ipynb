# %%
import sys; sys.path.append('..')
from osp import *
groups_train = COMPARISONS[0]
doc = get_random_doc()
sent = random.choice(doc.sentences)

# %%
extract_slice_feats(doc)
# Out:
# {'pos_IN': 140.46288906624102,
#  'pos_NN': 148.4437350359138,
#  'pos_NNS': 34.317637669592976,
#  'pos_DT': 102.15482841181166,
#  'pos_WDT': 7.980845969672785,
#  'pos_PRP': 43.89465283320032,
#  'pos_VBP': 28.731045490822027,
#  'pos_JJ': 64.64485235434957,
#  'pos_CD': 3.9904229848363926,
#  'pos_VBZ': 51.07741420590583,
#  'pos_CC': 23.942537909018355,
#  'pos_VBN': 16.75977653631285,
#  'pos_PRP$': 11.971268954509178,
#  'pos_TO': 19.952114924181963,
#  'pos_VB': 39.904229848363926,
#  'pos_MD': 11.1731843575419,
#  'pos_RB': 63.84676775738228,
#  'pos_NNP': 20.75019952114924,
#  'pos_WP': 1.5961691939345573,
#  'pos_POS': 3.9904229848363926,
#  'pos_JJR': 1.5961691939345573,
#  'pos_RBR': 3.9904229848363926,
#  'pos_VBG': 8.778930566640064,
#  'pos_WRB': 3.9904229848363926,
#  'pos_PDT': 1.5961691939345573,
#  'pos_NNPS': 3.1923383878691145,
#  'pos_VBD': 4.788507581803671,
#  'pos_EX': 3.1923383878691145,
#  'pos_RP': 3.9904229848363926,
#  'deprel_case': 98.96249002394254,
# ...

# %%
Counter(x.split('_')[0] for x in extract_slice_feats(doc).keys())
# Out:
# Counter({'phrase': 49, 'deprel': 39, 'pos': 29, 'sent': 8, 'ttr': 6})
