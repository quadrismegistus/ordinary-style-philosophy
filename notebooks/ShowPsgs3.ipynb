# %%
import sys; sys.path.append('..')
from osp.passages import *

# %%
id1='phil/10.2307/20118780'
id2='lit/25614398'

# %%
all_ids = set(STASH_SLICES_NLP.keys())

# %%
slice_id = random.choice(list(all_ids))

# %%
display_passage(slice_id, max_score=1, min_score=-1, color='weight',word_feat_type='deprel')
# Out:
# <div style="line-height: 2.8; font-family: sans-serif; padding: 10px;"><p><span style="background-color: rgba(255, 165, 0, 0.96); color: white; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">The<sub style="display: block; font-size: 0.7em; opacity: 0.7; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">question<sub style="display: block; font-size: 0.7em; opacity: 0.7; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nsubj:outer</sub></span><span style="background-color: rgba(0, 0, 255, 0.70); color: white; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding:
# ...

# %%
print(slice_id)
# Out:
# phil/10.2307/24654857__02

# %%
get_text_metadata(slice_id)
# Out:
# uuid                            c2f24dfe-551e-347f-bf84-242f97f0ec17
# title                     Poiesis and Praxis in Fundamental Ontology
# author                                             JACQUES TAMINIAUX
# year                                                            1987
# journal                                    Research in Phenomenology
# volume                                                            17
# issue                                                            NaN
# url                                jstor.org/stable/10.2307/24654857
# publisher                                                      Brill
# discipline                                                Philosophy
# decade                                                          1980
# period                                                     1980-2000
# century                                                          C20
# halfcentury                                                     lC20
# ...

# %%
get_passage('phil/10.2307/20118780__01')
# Out:
# ANTONY GALTON OPERATORS VS.
# ----------------------------------------------------------------------------------------------------
# ARGUMENTS: THE INS AND OUTS OF REIFICATION ABSTRACT.
# ----------------------------------------------------------------------------------------------------
# INTRODUCTION Temporal Logic has been a fertile battle-ground for philosophical and technical debate, from abstruse metaphysical questions through technicalities in mathematical logic to practical issues concerning computer implementation.
# ----------------------------------------------------------------------------------------------------
# One such debate concerns the general theme of reification.
# ----------------------------------------------------------------------------------------------------
# This term, which literally means 'thing-making', refers to the use of terms in first-order logic to express concepts normally expressed using predicates, operators, or even complete propositions.
# ...
