# %%
import sys
sys.path.append('..')
from osp import *

df_meta = get_corpus_metadata()

# %%
def get_recog_words(txt):
    return [
        w.lower() for w in tokenize_agnostic(txt)
        if w.strip().isalpha() and w.lower() in get_ok_words()
    ]

def count_recog_words(txt, n=SLICE_LEN):
    return Counter(get_recog_words(txt.lower())[:n])

def get_text_freqs(id, slice_len=SLICE_LEN, force=False):
    stash = HashStash(f'osp_freqs_slices_{slice_len}')
    if not force and id in stash:
        return {int(k):v for k,v in stash[id].items()}
    slices = get_text_slices(id)
    freqs = {
        int(slice_num): dict(count_recog_words(txt, slice_len))
        for slice_num, txt in slices.items()
    }
    stash[id] = freqs
    return freqs

# %%
def iter_slice_word_freqs(df_meta=None):
    df_meta = get_corpus_metadata() if df_meta is None else df_meta
    for id in tqdm(df_meta.index):
        for slice_num, freqs in get_text_freqs(id).items():
            yield id, slice_num, freqs

# %%
def get_words_freqs_slices(words, slice_len=SLICE_LEN):
    stash = HashStash(f'osp_word_freqs_slices_{slice_len}')
    # stash.clear()
    if not any(w not in stash for w in words):
        word2text2count = {
            w: stash[w]
            for w in words
        }
    else:        
        word2text2count = defaultdict(dict)
        for id, slice_num, freqs in iter_slice_word_freqs():
            for w, c in freqs.items():
                if w in words:
                    word2text2count[w][f'{id}__{slice_num:02d}'] = c

        for k,v in tqdm(list(word2text2count.items()), desc='saving to stash'):
            stash[k] = v

        for w in words:
            if w not in stash:
                stash[w] = {}

    return pd.DataFrame(word2text2count).rename_axis('id__slice')

# %%
# stash = HashStash(f'osp_word_freqs_slices_1000')
# stash

# %%
words = get_non_content_words()
# words =['insofar']
df_freqs = get_words_freqs_slices(words)
df_freqs
# Out:
# 100%|██████████| 57620/57620 [05:38<00:00, 170.26it/s]
# saving to stash: 100%|██████████| 641/641 [00:20<00:00, 30.83it/s]
#                              it    of   the  few    in   and  its  here   not  \
# id__slice
# phil/10.2307/40231690__01  15.0  55.0  67.0  1.0  26.0  31.0  3.0   2.0  17.0
# phil/10.2307/40231690__02  19.0  52.0  68.0  NaN  14.0  23.0  1.0   NaN   2.0
# phil/10.2307/40231690__03  22.0  48.0  57.0  NaN  24.0  24.0  3.0   1.0  11.0
# phil/10.2307/40231690__04  19.0  53.0  49.0  NaN  26.0  24.0  4.0   1.0  13.0
# phil/10.2307/40230399__01  22.0  51.0  49.0  NaN  15.0  20.0  NaN   1.0  12.0
# ...                         ...   ...   ...  ...   ...   ...  ...   ...   ...
# phil/10.2307/42964179__01   NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
# phil/10.2307/42968544__01   NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
# lit/458048__01              NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
# lit/457913__01              NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
# lit/457979__01              NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN
#
#                            without  ...  streamside  blimey  shush  ahhhh  \
# id__slice                           ...
# phil/10.2307/40231690__01      1.0  ...         NaN     NaN    NaN    NaN
# phil/10.2307/40231690__02      NaN  ...         NaN     NaN    NaN    NaN
# phil/10.2307/40231690__03      3.0  ...         NaN     NaN    NaN    NaN
# phil/10.2307/40231690__04      2.0  ...         NaN     NaN    NaN    NaN
# phil/10.2307/40230399__01      1.0  ...         NaN     NaN    NaN    NaN
# ...                            ...  ...         ...     ...    ...    ...
# phil/10.2307/42964179__01      NaN  ...         NaN     NaN    NaN    NaN
# phil/10.2307/42968544__01      NaN  ...         NaN     NaN    NaN    NaN
# lit/458048__01                 NaN  ...         NaN     NaN    NaN    NaN
# lit/457913__01                 NaN  ...         NaN     NaN    NaN    NaN
# lit/457979__01                 NaN  ...         NaN     NaN    NaN    NaN
#
#                            northeastward  downrange  meself  ciao  nyah  yuk
# id__slice
# phil/10.2307/40231690__01            NaN        NaN     NaN   NaN   NaN  NaN
# phil/10.2307/40231690__02            NaN        NaN     NaN   NaN   NaN  NaN
# phil/10.2307/40231690__03            NaN        NaN     NaN   NaN   NaN  NaN
# phil/10.2307/40231690__04            NaN        NaN     NaN   NaN   NaN  NaN
# phil/10.2307/40230399__01            NaN        NaN     NaN   NaN   NaN  NaN
# ...                                  ...        ...     ...   ...   ...  ...
# phil/10.2307/42964179__01            NaN        NaN     NaN   NaN   NaN  NaN
# phil/10.2307/42968544__01            NaN        NaN     NaN   NaN   NaN  NaN
# lit/458048__01                       NaN        NaN     NaN   NaN   NaN  NaN
# lit/457913__01                       NaN        NaN     NaN   NaN   NaN  NaN
# lit/457979__01                       NaN        NaN     NaN   NaN   NaN  NaN
#
# [186708 rows x 641 columns]

# %%
# df_freqs.sum(axis=1)

# %%
num_docs_s.loc['insofar']

# %%
non_content_words = get_non_content_words()
num_docs_s['is_non_content'] = num_docs_s.index.isin(non_content_words)
num_docs_s[num_docs_s.is_non_content].query('num_docs_rank < 10_000')
