# %%
import sys
sys.path.append('..')
from osp import *
df_meta = get_corpus_metadata(periodize_by=20).query('year>=1920 and year<2020')

# %%
words=['hence','insofar','the', 'thereby','therein']
words=get_non_content_words()

# %%
df_freqs = get_words_freqs_slices(words)
df_freqs
# Out:
#   0%|          | 0/57620 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_freqs = get_words_freqs_slices(words)
#       2 df_freqs
#
# File ~/github/ordinary-style-philosophy/notebooks/../osp.py:747, in get_words_freqs_slices(words, slice_len)
#     745 else:
#     746     word2text2count = defaultdict(dict)
# --> 747     for id, slice_num, freqs in iter_slice_word_freqs():
#     748         for w, c in freqs.items():
#     749             if w in words:
#
# File ~/github/ordinary-style-philosophy/notebooks/../osp.py:734, in iter_slice_word_freqs(df_meta)
#     732 df_meta = get_corpus_metadata() if df_meta is None else df_meta
#     733 for id in tqdm(df_meta.index):
# --> 734     for slice_num, freqs in get_text_freqs(id).items():
#     735         yield id, slice_num, freqs
#
# ...

# %%
(df_freqs).mean().sort_values(ascending=False).head(50)
# Out:
# the        69.482309
# of         47.825615
# to         30.036485
# and        24.316178
# a          24.053319
# in         23.698197
# that       20.335283
# it         11.578352
# as         10.804577
# for         8.851522
# not         8.669093
# this        8.570404
# we          6.328888
# by          6.299837
# or          6.197003
# which       6.077613
# with        6.031252
# but         5.648076
# an          5.375142
# on          5.265200
# his         4.721646
# he          4.513925
# from        4.201770
# if          3.686366
# at          3.501451
# what        3.459134
# there       3.101635
# they        3.048332
# all         2.923549
# its         2.798680
# so          2.685225
# such        2.683233
# no          2.561272
# more        2.420876
# these       2.393647
# their       2.350719
# about       2.168568
# some        2.159292
# our         2.087736
# any         1.844442
# than        1.836322
# between     1.782489
# when        1.779040
# ...
