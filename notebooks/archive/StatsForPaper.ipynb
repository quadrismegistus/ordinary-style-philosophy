# %%
import sys
sys.path.append('..')
from osp import *

# %%
df_meta = get_corpus_metadata()
df_meta.iloc[0]
# Out:
# uuid                      f6eecd30-8c4a-3c3d-a9da-4e777d091b2c
# title                                "Aristotlés" Horror Vacui
# author                                              John Thorp
# year                                                      1990
# journal                         Canadian Journal of Philosophy
# volume                                                      20
# issue                                                        2
# url                          jstor.org/stable/10.2307/40231690
# publisher                           Cambridge University Press
# discipline                                          Philosophy
# discipline_names                                           NaN
# decade                                                    1990
# period                                               1975-2000
# century                                                    C20
# halfcentury                                               lC20
# century_discipline                              C20 Philosophy
# halfcentury_discipline                         lC20 Philosophy
# period_discipline                         1975-2000 Philosophy
# decade_discipline                              1990 Philosophy
# century_journal             C20 Canadian Journal of Philosophy
# journal_orig                    Canadian Journal of Philosophy
# num_articles                                                 1
# num_slices                                                   4
# num_parsed_slices                                            1
# Name: phil/10.2307/40231690, dtype: object

# %%
df_meta.discipline.value_counts()
# Out:
# discipline
# Philosophy    32277
# Other         32277
# Literature    25343
# Name: count, dtype: int64

# %%
parsed_ids = set(get_parsed_slice_ids())
# len(parsed_ids)

# %%
parsed_counts = Counter()
for x in parsed_ids:
    parsed_counts[x.split("__")[0]] += 1
# parsed_counts

# %%
slice_counts = {x:len(y) for x,y in tqdm(STASH_SLICES.items(), total=len(STASH_SLICES))}
# Out:
# 100%|██████████| 89897/89897 [00:07<00:00, 11539.32it/s]

# %%
df_meta['num_articles'] = 1
df_meta['num_slices'] = [slice_counts[x] for x in df_meta.index]
df_meta['num_parsed_slices'] = [parsed_counts[x] for x in df_meta.index]
df_meta[['num_slices', 'num_parsed_slices']]
# Out:
#                         num_slices  num_parsed_slices
# id
# phil/10.2307/40231690            4                  1
# phil/10.2307/40230399            1                  0
# phil/10.2307/40231533            1                  1
# phil/10.2307/40230622            1                  1
# phil/10.2307/40231225            0                  0
# ...                            ...                ...
# other/10.2307/44827520           0                  0
# other/10.2307/44823154           0                  0
# other/10.2307/44823659           0                  0
# other/10.2307/44823625           0                  0
# other/10.2307/44823592           0                  0
#
# [89897 rows x 2 columns]

# %%
aggs = []
for disc in ['Philosophy', 'Literature', 'Other']:

    agg = df_meta.query('discipline == @disc').groupby(['discipline','period']).agg(
        {
            'journal':'nunique',
            'author':'nunique',
            'num_articles': 'sum',
            'num_slices': 'sum',
            'num_parsed_slices': 'sum',
        }
    )
    aggs.append(agg)

odf = pd.concat(aggs)
odf.columns = ['# Journals', '# Authors', '# Articles', '# Slices', '# Parsed Slices']
odf = odf.applymap(lambda x: f'{int(x):,d}')
odf
# Out:
#                      # Journals # Authors # Articles # Slices # Parsed Slices
# discipline period
# Philosophy 1900-1925          4       841      1,828    7,498           5,011
#            1925-1950          9     1,739      4,220   12,096           5,013
#            1950-1975         10     3,288      6,760   19,095           5,023
#            1975-2000         11     4,776      8,369   31,959           5,737
#            2000-2025         11     7,462     11,100   53,749           9,654
# Literature 1900-1925          3     1,064      2,458    4,238           4,238
#            1925-1950          5     2,639      5,080    7,357           5,013
#            1950-1975          7     3,791      5,510   12,224           5,011
#            1975-2000          7     4,657      6,378   21,199           5,028
#            2000-2025          7     4,658      5,917   17,293           5,018
# Other      1900-1925        312     1,211      1,828    1,587           1,587
#            1925-1950        645     3,315      4,220    3,966           3,966
#            1950-1975      1,142     5,892      6,760    6,679           5,009
#            1975-2000      1,771     7,611      8,369   10,373           5,016
#            2000-2025      1,971     9,783     11,100   15,402           5,013

# %%
print(df_to_latex_table(odf.reset_index()))
# Out:
# \begin{table}[H]
#   \centering
#   \small
#   \begin{tabular}{lllllll}
#   \toprule
#   discipline & period & \# Journals & \# Authors & \# Articles & \# Slices & \# Parsed Slices \\
#   \midrule
#   Philosophy & 1900-1925 & 4 & 841 & 1,828 & 7,498 & 5,011 \\
#   Philosophy & 1925-1950 & 9 & 1,739 & 4,220 & 12,096 & 5,013 \\
#   Philosophy & 1950-1975 & 10 & 3,288 & 6,760 & 19,095 & 5,023 \\
#   Philosophy & 1975-2000 & 11 & 4,776 & 8,369 & 31,959 & 5,737 \\
#   Philosophy & 2000-2025 & 11 & 7,462 & 11,100 & 53,749 & 9,654 \\
#   Literature & 1900-1925 & 3 & 1,064 & 2,458 & 4,238 & 4,238 \\
#   Literature & 1925-1950 & 5 & 2,639 & 5,080 & 7,357 & 5,013 \\
#   Literature & 1950-1975 & 7 & 3,791 & 5,510 & 12,224 & 5,011 \\
#   Literature & 1975-2000 & 7 & 4,657 & 6,378 & 21,199 & 5,028 \\
#   Literature & 2000-2025 & 7 & 4,658 & 5,917 & 17,293 & 5,018 \\
#   Other & 1900-1925 & 312 & 1,211 & 1,828 & 1,587 & 1,587 \\
#   Other & 1925-1950 & 645 & 3,315 & 4,220 & 3,966 & 3,966 \\
#   Other & 1950-1975 & 1,142 & 5,892 & 6,760 & 6,679 & 5,009 \\
#   Other & 1975-2000 & 1,771 & 7,611 & 8,369 & 10,373 & 5,016 \\
#   Other & 2000-2025 & 1,971 & 9,783 & 11,100 & 15,402 & 5,013 \\
#   \bottomrule
#   \end{tabular}
# \end{table}

# %%
s=df_meta[df_meta['discipline'] == 'Literature'].journal.value_counts()
l = []
for k,v in s.items():
    ymin = df_meta[df_meta.journal == k].year.min()
    ymax = df_meta[df_meta.journal == k].year.max()
    l.append(f'{k} ({ymin}-{ymax}, n={v:,})')
print('\n'.join(l))
# Out:
# PMLA (1900-2016, n=7,258)
# The Modern Language Review (1905-2018, n=5,698)
# The Review of English Studies (1925-2016, n=3,008)
# Modern Philology (1903-2018, n=2,997)
# ELH (1934-2016, n=2,619)
# New Literary History (1969-2016, n=1,928)
# Critical Inquiry (1974-2019, n=1,835)

# %%
len(l)
# Out:
# 7

# %%
def get_num_parsed_slices(id):
    return len([x for x in parsed_ids if x.startswith(id)])

df_meta['num_parsed_slices'] = [get_num_parsed_slices(id) for id in tqdm(df_meta.index)]
# Out:
# 100%|██████████| 89897/89897 [06:41<00:00, 223.76it/s]

# %%
df_feats = pd.read_pickle('../data/raw/df_feats.pkl.gz')
df_feats['weight_abs'] = df_feats['weight'].abs()
df_feats = df_feats.groupby('feature').mean(numeric_only=True).reset_index().drop(columns=['run']).sort_values('weight_abs',ascending=False)    
# df_feats1 = df_feats[df_feats.comparison.str.contains('Philosophy') & df_feats.comparison.str.contains('Other')].groupby('feature').mean(numeric_only=True).reset_index().drop(columns=['run']).sort_values('weight_abs',ascending=False)
# df_feats2 = df_feats1.copy()
# df_feats2['feat_type'] = df_feats2['feature'].apply(lambda x: x.split('_')[0])
# df_feats2['num'] = 1

# df_feats2.groupby('feat_type').agg(
#     {
#         'num': 'sum',
#         'weight_abs': 'max',
#     }
# ).sort_values('num',ascending=False)

# %%
df = STASH_SLICE_FEATS.df

# %%
df0 = df[[c for c in df.columns if c not in BAD_SLICE_FEATS and not c.startswith('phrase_')]]
df0
# Out:
#                                 pos_DT    pos_VBZ     pos_RB      pos_JJ  \
# _key
# phil/10.2307/2380200__04     84.104289  46.257359  81.581161  116.904962
# other/10.2307/2514892__02    87.415222  20.346647  16.578749   97.211756
# other/10.2307/14710__03     102.811245  11.244980  46.586345  100.401606
# phil/10.2307/20111773__02    98.193244  56.559309  56.559309   98.193244
# phil/10.2307/2379466__05     91.644205  32.345013  65.588500   79.065588
# ...                                ...        ...        ...         ...
# lit/468421__06              116.161616  40.404040  44.612795   75.757576
# other/10.2307/29782027__24   80.839895  18.372703  29.921260   51.968504
# lit/459531__04               92.471358  40.098200  36.824877   80.196399
# lit/433908__02               41.918581   8.464329  11.688835   38.694075
# phil/10.2307/2185617__06     91.458154  56.082830  58.671268   63.848145
#
#                                 pos_IN      pos_NN   pos_PRP$    pos_NNS  \
# _key
# phil/10.2307/2380200__04    111.017662  102.607233  15.979815  45.416316
# other/10.2307/2514892__02   143.180106  113.790505   5.275057  66.314996
# other/10.2307/14710__03     130.120482  167.068273  12.048193  52.208835
# phil/10.2307/20111773__02   135.113904  109.190888   6.284368  35.349568
# phil/10.2307/2379466__05    139.263252  141.958670  11.680144  53.908356
# ...                                ...         ...        ...        ...
# lit/468421__06              136.363636  162.457912  11.784512  54.713805
# other/10.2307/29782027__24   70.341207   87.664042   0.524934  25.721785
# lit/459531__04              135.842881  134.206219  18.003273  49.099836
# lit/433908__02               71.342201   84.240226   4.836759  38.291012
# phil/10.2307/2185617__06    165.660052  148.403796  21.570319  44.003451
#
#                                pos_TO     pos_VB  ...  deprel_dislocated  \
# _key                                              ...
# phil/10.2307/2380200__04    22.708158  58.031960  ...                NaN
# other/10.2307/2514892__02    5.275057  11.303693  ...                NaN
# other/10.2307/14710__03      8.032129  17.670683  ...                NaN
# phil/10.2307/20111773__02    9.426551  24.351925  ...           0.785546
# phil/10.2307/2379466__05    12.578616  40.431267  ...                NaN
# ...                               ...        ...  ...                ...
# lit/468421__06              14.309764  37.878788  ...                NaN
# other/10.2307/29782027__24   7.349081  25.721785  ...                NaN
# lit/459531__04              21.276596  32.733224  ...                NaN
# lit/433908__02               1.612253  10.076582  ...                NaN
# phil/10.2307/2185617__06    17.256255  38.826575  ...                NaN
#
#                             deprel_csubj:pass  deprel_advcl:relcl   pos_NFP  \
# _key
# phil/10.2307/2380200__04                  NaN                 NaN       NaN
# other/10.2307/2514892__02                 NaN                 NaN       NaN
# other/10.2307/14710__03                   NaN                 NaN       NaN
# phil/10.2307/20111773__02                 NaN                 NaN       NaN
# phil/10.2307/2379466__05             0.898473                 NaN       NaN
# ...                                       ...                 ...       ...
# lit/468421__06                       0.841751            0.841751       NaN
# other/10.2307/29782027__24                NaN                 NaN  5.249344
# lit/459531__04                            NaN                 NaN       NaN
# lit/433908__02                            NaN                 NaN       NaN
# phil/10.2307/2185617__06                  NaN            0.862813       NaN
#
#                             deprel_vocative   pos_SYM  deprel_orphan  pos_AFX  \
# _key
# phil/10.2307/2380200__04                NaN       NaN            NaN      NaN
# other/10.2307/2514892__02               NaN       NaN            NaN      NaN
# other/10.2307/14710__03                 NaN       NaN            NaN      NaN
# phil/10.2307/20111773__02               NaN       NaN            NaN      NaN
# phil/10.2307/2379466__05                NaN       NaN            NaN      NaN
# ...                                     ...       ...            ...      ...
# lit/468421__06                          NaN       NaN            NaN      NaN
# other/10.2307/29782027__24              NaN  0.524934            NaN      NaN
# lit/459531__04                          NaN       NaN            NaN      NaN
# lit/433908__02                     5.239823       NaN            NaN      NaN
# phil/10.2307/2185617__06                NaN       NaN       0.862813      NaN
#
#                             deprel_goeswith  pos_GW
# _key
# phil/10.2307/2380200__04                NaN     NaN
# other/10.2307/2514892__02               NaN     NaN
# other/10.2307/14710__03                 NaN     NaN
# phil/10.2307/20111773__02               NaN     NaN
# phil/10.2307/2379466__05                NaN     NaN
# ...                                     ...     ...
# lit/468421__06                          NaN     NaN
# other/10.2307/29782027__24              NaN     NaN
# lit/459531__04                          NaN     NaN
# lit/433908__02                          NaN     NaN
# phil/10.2307/2185617__06                NaN     NaN
#
# [76597 rows x 99 columns]

# %%
dfz = df0.copy().fillna(0)
for c in dfz.columns:
    dfz[c] = (dfz[c] - dfz[c].mean()) / dfz[c].std()
dfz['discipline'] = dfz.index.map(lambda x: x.split('/')[0])
dfz
# Out:
#                               pos_DT   pos_VBZ    pos_RB    pos_JJ    pos_IN  \
# _key
# phil/10.2307/2380200__04   -0.971340  0.842103  3.045618  2.142348 -1.341446
# other/10.2307/2514892__02  -0.793884 -0.942321 -2.223544  1.108831  0.433220
# other/10.2307/14710__03     0.031297 -1.569136  0.208902  1.276237 -0.287387
# phil/10.2307/20111773__02  -0.216215  1.551580  1.017321  1.160340 -0.011859
# phil/10.2307/2379466__05   -0.567223 -0.116015  1.749236  0.156503  0.217095
# ...                              ...       ...       ...       ...       ...
# lit/468421__06              0.746837  0.438996  0.048924 -0.017104  0.057099
# other/10.2307/29782027__24 -1.146302 -1.078263 -1.141986 -1.265576 -3.585900
# lit/459531__04             -0.522890  0.417933 -0.582372  0.215849  0.028365
# lit/433908__02             -3.232368 -1.760635 -2.619925 -1.962230 -3.530667
# phil/10.2307/2185617__06   -0.577195  1.518766  1.188519 -0.642122  1.673622
#
#                               pos_NN  pos_PRP$   pos_NNS    pos_TO    pos_VB  \
# _key
# phil/10.2307/2380200__04   -1.599537  0.547509 -0.159382  1.635407  2.212708
# other/10.2307/2514892__02  -1.207474 -0.946357  0.867249 -1.367570 -1.633699
# other/10.2307/14710__03     0.660334 -0.001156  0.174295 -0.892644 -1.109605
# phil/10.2307/20111773__02  -1.368727 -0.805506 -0.653903 -0.652445 -0.559643
# phil/10.2307/2379466__05   -0.219957 -0.052517  0.257783 -0.109479  0.763918
# ...                              ...       ...       ...       ...       ...
# lit/468421__06              0.498704 -0.037953  0.297350  0.188723  0.553812
# other/10.2307/29782027__24 -2.123414 -1.609244 -1.126860 -1.010304 -0.446883
# lit/459531__04             -0.491742  0.829885  0.021568  1.388810  0.130259
# lit/433908__02             -2.243446 -1.007522 -0.509407 -1.998514 -1.734708
# phil/10.2307/2185617__06    0.005996  1.327672 -0.228788  0.696278  0.631829
#
#                             ...  deprel_csubj:pass  deprel_advcl:relcl  \
# _key                        ...
# phil/10.2307/2380200__04    ...          -0.353549           -0.640164
# other/10.2307/2514892__02   ...          -0.353549           -0.640164
# other/10.2307/14710__03     ...          -0.353549           -0.640164
# phil/10.2307/20111773__02   ...          -0.353549           -0.640164
# phil/10.2307/2379466__05    ...           2.239801           -0.640164
# ...                         ...                ...                 ...
# lit/468421__06              ...           2.076079            0.502096
# other/10.2307/29782027__24  ...          -0.353549           -0.640164
# lit/459531__04              ...          -0.353549           -0.640164
# lit/433908__02              ...          -0.353549           -0.640164
# phil/10.2307/2185617__06    ...          -0.353549            0.530677
#
#                              pos_NFP  deprel_vocative   pos_SYM  \
# _key
# phil/10.2307/2380200__04   -0.227423        -0.388949 -0.199913
# other/10.2307/2514892__02  -0.227423        -0.388949 -0.199913
# other/10.2307/14710__03    -0.227423        -0.388949 -0.199913
# phil/10.2307/20111773__02  -0.227423        -0.388949 -0.199913
# phil/10.2307/2379466__05   -0.227423        -0.388949 -0.199913
# ...                              ...              ...       ...
# lit/468421__06             -0.227423        -0.388949 -0.199913
# other/10.2307/29782027__24  4.888631        -0.388949  0.269162
# lit/459531__04             -0.227423        -0.388949 -0.199913
# lit/433908__02             -0.227423         8.113293 -0.199913
# phil/10.2307/2185617__06   -0.227423        -0.388949 -0.199913
#
#                             deprel_orphan   pos_AFX  deprel_goeswith  pos_GW  \
# _key
# phil/10.2307/2380200__04        -0.174895 -0.145034         -0.01923 -0.0456
# other/10.2307/2514892__02       -0.174895 -0.145034         -0.01923 -0.0456
# other/10.2307/14710__03         -0.174895 -0.145034         -0.01923 -0.0456
# phil/10.2307/20111773__02       -0.174895 -0.145034         -0.01923 -0.0456
# phil/10.2307/2379466__05        -0.174895 -0.145034         -0.01923 -0.0456
# ...                                   ...       ...              ...     ...
# lit/468421__06                  -0.174895 -0.145034         -0.01923 -0.0456
# other/10.2307/29782027__24      -0.174895 -0.145034         -0.01923 -0.0456
# lit/459531__04                  -0.174895 -0.145034         -0.01923 -0.0456
# lit/433908__02                  -0.174895 -0.145034         -0.01923 -0.0456
# phil/10.2307/2185617__06         5.771150 -0.145034         -0.01923 -0.0456
#
#                             discipline
# _key
# phil/10.2307/2380200__04          phil
# other/10.2307/2514892__02        other
# other/10.2307/14710__03          other
# phil/10.2307/20111773__02         phil
# phil/10.2307/2379466__05          phil
# ...                                ...
# lit/468421__06                     lit
# other/10.2307/29782027__24       other
# lit/459531__04                     lit
# lit/433908__02                     lit
# phil/10.2307/2185617__06          phil
#
# [76597 rows x 100 columns]

# %%
stash_eg = get_stash('osp_feat_examples3')
stash_eg_df = stash_eg.df
feat2eg = dict(zip(stash_eg_df.feature, stash_eg_df.eg_text))
# feat2eg

# %%
stash_eg2 = get_stash('osp_feat_examples2')
l = []
for id,idld in tqdm(stash_eg2.items(), total=len(stash_eg2)):
    if id.startswith('phil'):
        idd = random.choice(idld)
        l.append(idd)
# Out:
# 100%|██████████| 33666/33666 [01:10<00:00, 476.87it/s]

# %%
ldf = pd.DataFrame(l).sample(frac=1)
ldf['eg_text_len'] = ldf.eg_text.apply(len)
ldf.sort_values('eg_text_len',ascending=False,inplace=True)
ldf.drop_duplicates(subset='feature',inplace=True)
ldf.feature.nunique()
# Out:
# 97

# %%
def shorten_eg(eg, max_len=40):
    eg_pre,w,eg_post = eg.split('*',2)
    radius = (max_len - len(w)) // 2
    eg_pre = eg_pre[-radius:]
    eg_post = eg_post[:max_len-len(eg_pre)-len(w)]
    return f'{eg_pre}XXXEMPHXXX{{{w.lower()}}}{eg_post}'

ldf['eg_short'] = ldf.eg_text.apply(shorten_eg)

feat2eg = dict(zip(ldf.feature, ldf.eg_short))
# ldf

# %%
dftf = df0.copy().fillna(0)
dftf['discipline'] = dftf.index.map(lambda x: x.split('/')[0])
dftf = dftf.groupby('discipline').mean().T.round(0).applymap(int).applymap(str)
feat2tf = dict(zip(dftf.index, dftf.phil))
# feat2tf

# %%
dfagg = dfz.groupby('discipline').mean().T.sort_values('phil',ascending=False).rename_axis('feature')
# dfagg = dfagg.round(2).applymap(lambda x: f'+{x}' if x>0 else f'{x}')
dfagg = dfagg.round(2).applymap(str)
dfagg['feat_desc'] = dfagg.index.map(lambda x: f'{FEAT2DESC[x]} ({x.split("_")[0]})')
dfagg['eg'] = dfagg.index.map(lambda x: '' if x not in feat2eg else '...'+feat2eg[x].strip()+'...')
dfagg['phil_tf'] = dfagg.index.map(feat2tf)
# dfagg['feat_type'] = dfagg.index.map(lambda x: x.split('_')[0])
# dfagg = dfagg[['feat_desc','eg','phil','lit','other']].fillna('').reset_index()
dfagg = dfagg[['feat_desc','eg','phil_tf','phil']].fillna('').reset_index().drop(columns=['feature'])
dfagg.columns = ['Feature', 'Example', 'Average', 'Z-score']
# dfagg = dfagg.set_index(['Feature','Description','Example'])
dfagg
# Out:
#                                   Feature  \
# 0                         Copula (deprel)
# 1                         Marker (deprel)
# 2              # Dependent clauses (sent)
# 3                             Modal (pos)
# 4      Verb, 3rd person sing. pres. (pos)
# ..                                    ...
# 94       Type-token ratio for nouns (ttr)
# 95            Mean type-token ratio (ttr)
# 96  # Words in independent clauses (sent)
# 97                 Verb, past tense (pos)
# 98            Proper noun, singular (pos)
#
#                                                        Example Average Z-score
# 0   ...er verbal symbols, XXXEMPHXXX{is} either directly or...      27    0.65
# 1   ...rom its nature, XXXEMPHXXX{whereas} only finite prop...      45    0.62
# 2                                                                   79    0.54
# 3   ...use of what they XXXEMPHXXX{would} imply for a norma...      16    0.54
# 4    ...the novelty that XXXEMPHXXX{has} impressed thinkers...      42    0.53
# ..                                                         ...     ...     ...
# 94                                                                   0   -0.41
# 95                                                                   0   -0.41
# 96                                                                 376   -0.46
# 97   ...and o-minimality XXXEMPHXXX{became} one of the most...       6   -0.48
# 98  ...objections to HumeXXXEMPHXXX{hume} which were so dif...      20   -0.54
#
# [99 rows x 4 columns]

# %%
out=df_to_latex_table(dfagg.head(25), caption="""
Top 25 most distinctive features of philosophy articles. Averages reflect average frequency per 1,000 words. Z-scores express the number of standard deviations from the mean frequency across all articles in the corpus.
""".strip())
out = out.replace("XXXEMPHXXX\{","\\textbf{")
out = out.replace("\\}","}")
print(out)
# Out:
# \begin{table}[H]
#   \centering
#   \small
#   \begin{tabular}{llll}
#   \toprule
#   Feature & Example & Average & Z-score \\
#   \midrule
#   Copula (deprel) & ...er verbal symbols, \textbf{is} either directly or... & 27 & 0.65 \\
#   Marker (deprel) & ...rom its nature, \textbf{whereas} only finite prop... & 45 & 0.62 \\
#   \# Dependent clauses (sent) &  & 79 & 0.54 \\
#   Modal (pos) & ...use of what they \textbf{would} imply for a norma... & 16 & 0.54 \\
#   Verb, 3rd person sing. pres. (pos) & ...the novelty that \textbf{has} impressed thinkers... & 42 & 0.53 \\
#   Verb, base form (pos) & ..., it could never \textbf{occur} to anyone to cont... & 37 & 0.52 \\
#   \# Clause transitions (sent) &  & 126 & 0.51 \\
#   Clausal complement (deprel) & ...tensed sentences \textbf{have} these token-refle... & 9 & 0.5 \\
#   Expletive (deprel) & ...he literal sense), \textbf{it} goes without sayin... & 6 & 0.47 \\
#   \# Unique clauses (sent) &  & 110 & 0.46 \\
#   \# Words in dependent clauses (sent) &  & 507 & 0.45 \\
#   Adverb (pos) & ...nnovators develop \textbf{here} and there scatter... & 50 & 0.45 \\
#   Outer clause nominal subject (deprel) & ..., of course: his \textbf{point} was that, thus fa... & 2 & 0.45 \\
#   Nominal subject (deprel) & ...tead: to know what \textbf{it} is like to experie... & 66 & 0.44 \\
#   Verb, non-3rd person sing. pres. (pos) & ...but all of which \textbf{have} definite esthetic... & 21 & 0.44 \\
#   Adverbial modifier (deprel) & ...attitudes which \textbf{securely} belong to the a... & 55 & 0.44 \\
#   Wh-determiner (pos) & ...if the means by \textbf{which} that is accomplis... & 10 & 0.42 \\
#   Auxiliary (deprel) & ...lativist, for one \textbf{may} hold that what is... & 24 & 0.4 \\
#   Relative clause modifier (deprel) & ...are explicitly \textbf{committed} to keeping dist... & 14 & 0.38 \\
#   Existential there (pos) & ..., in cases where \textbf{there} is an upper limit... & 3 & 0.37 \\
#   Adverbial clause modifier (deprel) & ...s paper will be \textbf{familiar} with what is me... & 19 & 0.35 \\
#   Clausal subject (deprel) & ...e acts that we do \textbf{has} countless effects,... & 2 & 0.35 \\
#   Maximum clause depth (sent) &  & 90 & 0.33 \\
#   Personal pronoun (pos) & ...psychologists tell \textbf{us} is right, at any g... & 36 & 0.33 \\
#   to (pos) & ...ce for Dutch Books \textbf{to} be an issue we nee... & 15 & 0.29 \\
#   \bottomrule
#   \end{tabular}
#   \caption{Top 25 most distinctive features of philosophy articles. Averages reflect average frequency per 1,000 words. Z-scores express the number of standard deviations from the mean frequency across all articles in the corpus.}
# \end{table}
