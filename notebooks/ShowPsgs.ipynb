# %%
import sys; sys.path.append('..')
from osp import *
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sys; sys.path.append('..')
# ----> 2 from osp import *
#
# File ~/github/ordinary-style-philosophy/notebooks/../osp.py:13
#      11 import nltk
#      12 from collections import defaultdict
# ---> 13 import stanza
#      14 import re
#      15 import plotnine as p9
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/stanza/__init__.py:1
# ----> 1 from stanza.pipeline.core import DownloadMethod, Pipeline
#       2 from stanza.pipeline.multilingual import MultilingualPipeline
#       3 from stanza.models.common.doc import Document
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/stanza/pipeline/core.py:17
#      15 from stanza.pipeline._constants import *
#      16 from stanza.models.common.constant import langcode_to_lang
# ---> 17 from stanza.models.common.doc import Document
#      18 from stanza.models.common.foundation_cache import FoundationCache
#      19 from stanza.models.common.utils import default_device
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/stanza/models/common/doc.py:17
#      14 import networkx as nx
#      16 from stanza.models.common.stanza_object import StanzaObject
# ---> 17 from stanza.models.common.utils import misc_to_space_after, space_after_to_misc, misc_to_space_before, space_before_to_misc
#      18 from stanza.models.ner.utils import decode_from_bioes
#      19 from stanza.models.constituency import tree_reader
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/stanza/models/common/utils.py:19
#      16 import unicodedata
#      17 import zipfile
# ---> 19 import torch
#      20 import numpy as np
#      22 from stanza.models.common.constant import lcode2lang
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/__init__.py:2680
#    2676 from torch.func import vmap as vmap
#    2679 if not TYPE_CHECKING:
# -> 2680     from torch import _meta_registrations
#    2682 # Enable CUDA Sanitizer
#    2683 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_meta_registrations.py:12
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#      15     global_decomposition_table,
#      16     meta_table,
#      17 )
#      18 from torch._ops import OpOverload
#      19 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_decomp/__init__.py:277
#     275 # populate the table
#     276 import torch._decomp.decompositions
# --> 277 import torch._refs
#     280 def core_aten_decompositions() -> "CustomDecompTable":
#     281     from torch.export.exported_program import default_decompositions
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_refs/__init__.py:6762
#    6751 # Views
#    6752 # We can't model these as above, as the pattern of doing `op(a, out=a)` does not work for a view function
#    6753 # given that it does not reshape the input (it just copies the result into it)
#    (...)   6757 # transpose_ = _make_inplace(transpose)
#    6758 # unsqueeze_ = _make_inplace(unsqueeze)
#    6761 import torch._refs._conversions
# -> 6762 import torch._refs.fft
#    6763 import torch._refs.linalg
#    6764 import torch._refs.nn.functional
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_refs/fft.py:249
#     238 @register_decomposition(aten.fft_irfft)
#     239 @out_wrapper()
#     240 def irfft(
#    (...)    244     norm: NormType = None,
#     245 ) -> TensorLikeType:
#     246     return _fft_c2r("irfft", input, n, dim, norm, forward=False)
# --> 249 @register_decomposition(aten.fft_hfft)
#     250 @out_wrapper()
#     251 def hfft(
#     252     input: TensorLikeType,
#     253     n: Optional[int] = None,
#     254     dim: int = -1,
#     255     norm: NormType = None,
#     256 ) -> TensorLikeType:
#     257     return _fft_c2r("hfft", input, n, dim, norm, forward=True)
#     260 @register_decomposition(aten.fft_ihfft)
#     261 @out_wrapper()
#     262 def ihfft(
#    (...)    266     norm: NormType = None,
#     267 ) -> TensorLikeType:
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_decomp/__init__.py:218, in register_decomposition.<locals>.decomposition_decorator(fn)
#     215     _add_op_to_registry(registry, op, fn)
#     217 # To handle allowing multiple aten_ops at once
# --> 218 pytree.tree_map_(register, aten_op)
#     219 return orig_fn
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/utils/_pytree.py:1409, in tree_map_(func, tree, is_leaf, *rests)
#    1407 leaves, treespec = tree_flatten(tree, is_leaf=is_leaf)
#    1408 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# -> 1409 deque(map(func, *flat_args), maxlen=0)  # consume and exhaust the iterable
#    1410 return tree
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_decomp/__init__.py:215, in register_decomposition.<locals>.decomposition_decorator.<locals>.register(op)
#     214 def register(op):
# --> 215     _add_op_to_registry(registry, op, fn)
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_decomp/__init__.py:81, in _add_op_to_registry(registry, op, fn)
#      79     assert isinstance(op, OpOverloadPacket)
#      80     for ol in op.overloads():
# ---> 81         overloads.append(getattr(op, ol))
#      83 for op_overload in overloads:
#      84     if op_overload in registry:
#
# File ~/github/ordinary-style-philosophy/venv/lib/python3.11/site-packages/torch/_ops.py:1224, in OpOverloadPacket.__getattr__(self, key)
#    1219     raise AttributeError(
#    1220         f"The underlying op of '{str(self)}' has no overload name '{key}'"
#    1221     )
#    1223 op_, op_dk_, tags = op_dk_tags
# -> 1224 schema = torch._C._get_schema(self._qualified_op_name, use_key)
#    1225 overload: OpOverload[_P, _T] = (
#    1226     OpOverload(self, op_, op_dk_, schema, tags)
#    1227     if not _has_script_object_arg(schema)
#    1228     else TorchBindOpOverload(self, op_, op_dk_, schema, tags)
#    1229 )
#    1230 # cache the overload object
#
# KeyboardInterrupt:

# %%
PATH_FEAT_SCORES = os.path.join(PATH_DATA, 'feat_weights.xlsx')

feat_comparisons = [
    # 'Philosophy vs Literature',
    'C20 Philosophy vs C20 Literature',
    # 'Synthese vs PMLA',
    # 'The Philosophical Review vs The Modern Language Review',
]

def get_feat_scores(fn=PATH_FEAT_SCORES, comparisons=feat_comparisons):
    df = pd.read_excel(fn)
    df = df.query('comparison in @comparisons')
    for c in ['Unnamed: 0', 'Unnamed: 0.1']:
        if c in df.columns:
            df.drop(columns=[c], inplace=True)
    return df.set_index('feature')

# %%
df_feats=get_feat_scores()
df_feats.reset_index().feature.unique()
# Out:
# array(['pos_NN', 'pos_DT', 'pos_NNP', 'pos_NNS', 'pos_RB', 'pos_JJ',
#        'pos_VBP', 'pos_VBZ', 'pos_VB', 'pos_IN', 'deprel_punct', 'pos_MD',
#        'pos_FW', 'pos_SYM', 'pos_PRP', 'pos_EX', 'deprel_mark', 'pos_CC',
#        'pos_GW', 'pos_CD', 'sent_height', 'pos_VBG', 'pos_UH', 'pos_VBN',
#        'deprel_cop', 'pos_WRB', 'deprel_discourse', 'pos_WDT', 'pos_JJS',
#        'pos_JJR', 'deprel_ccomp', 'pos_HYPH', 'deprel_goeswith',
#        'deprel_vocative', 'deprel_cc', 'pos_WP', 'pos_RP', 'pos_PDT',
#        'deprel_csubj', 'pos_RBR', 'deprel_acl', 'pos_NFP',
#        'deprel_compound', 'deprel_dep', 'deprel_nummod', 'pos_RBS',
#        'pos_AFX', 'deprel_fixed', 'deprel_orphan', 'deprel_obj',
#        'deprel_dislocated', 'deprel_obl', 'deprel_iobj', 'pos_POS',
#        'deprel_reparandum', 'pos_NNPS', 'deprel_aux', 'deprel_xcomp',
#        'deprel_advcl', 'pos_TO', 'deprel_parataxis', 'deprel_nmod',
#        'deprel_appos', 'pos_VBD', 'deprel_expl', 'deprel_amod',
#        'deprel_case', 'deprel_advmod', 'deprel_nsubj', 'deprel_root',
#        'deprel_conj', 'deprel_det'], dtype=object)

# %%
def get_slice_ids(id, n_slices=10,stash=None):
    if stash is None:
        stash = STASH_SLICES_NLP
    
    return [
        f'{id}__{slice_id:02d}'
        for slice_id in range(1,n_slices+1)
        if f'{id}__{slice_id:02d}' in stash
    ]

# %%
slice_ids = get_slice_ids(id)
slice_id = slice_ids[0]

# %%
df_feat_scores = df_feats.groupby('feature').mean(numeric_only=True)
df_feat_scores['odds_ratio_log'] = np.log10(df_feat_scores['odds_ratio'])
color_by_feat_score = dict(zip(df_feat_scores.index, df_feat_scores['odds_ratio_log']))

# %%
def get_passage(slice_id, color_by=color_by_feat_score):
    docstr = STASH_SLICES_NLP[slice_id]
    doc = stanza.Document.from_serialized(docstr)

    for sent in doc.sentences:
        print(sent.text)
        print('-'*100)

# %%
from IPython.display import HTML
import html

def display_passage(slice_id, color_by=color_by_feat_score):
    """
    Displays the passage for a given slice_id in HTML.
    Annotates words with POS and deprel, and colors them by their weight in color_by.
    """
    if slice_id not in STASH_SLICES_NLP:
        print(f"Slice ID {slice_id} not found.")
        return
        
    docstr = STASH_SLICES_NLP[slice_id]
    doc = stanza.Document.from_serialized(docstr)
    
    output_html = ['<div style="line-height: 2.8; font-family: sans-serif; padding: 10px;">']
    
    min_score = min(color_by.values())
    max_score = max(color_by.values())

    for sent in doc.sentences:
        sent_html = []
        for word in sent.words:
            # Match the feature naming convention used in the codebase (pos_TAG, deprel_REL)
            pos = word.xpos or word.upos
            deprel = word.deprel
            
            # Combine scores for the word's features
            score = color_by.get(f'pos_{pos}', 0) + color_by.get(f'deprel_{deprel}', 0)
            
            # Map score to color intensity (clamped to [-1, 1])
            # Blue (1) to Orange (-1)
            intensity = max(min_score, min(max_score, score))
            
            if intensity > 0:
                # Positive score -> Blue
                bg_color = f'rgba(0, 0, 255, {intensity:.2f})'
                text_color = 'white' if intensity > 0.5 else 'black'
            elif intensity < 0:
                # Negative score -> Orange
                bg_color = f'rgba(255, 165, 0, {-intensity:.2f})'
                text_color = 'white' if -intensity > 0.5 else 'black'
            else:
                bg_color = 'transparent'
                text_color = 'black'
            
            # Escape text for safety and create annotated span
            safe_text = html.escape(word.text)
            word_span = (
                f'<span style="background-color: {bg_color}; color: {text_color}; font-size: 1.2em; '
                f'display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; '
                f'padding: 0 2px;">'
                f'{safe_text}'
                f'<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">'
                f'{pos}/{deprel}</sub>'
                f'</span>'
            )
            sent_html.append(word_span)
        
        output_html.append(f'<p style="margin-bottom: 25px;">{" ".join(sent_html)}</p>')
    
    output_html.append('</div>')
    return HTML("".join(output_html))

# %%
id1='phil/10.2307/20118780'
id2='lit/25614398'

# %%
for psg in get_slice_ids(id1):
    display(display_passage(psg))
# Out:
# <div style="line-height: 2.8; font-family: sans-serif; padding: 10px;"><p style="margin-bottom: 25px;"><span style="background-color: rgba(255, 165, 0, 0.26); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">ANTONY<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNP/root</sub></span> <span style="background-color: rgba(255, 165, 0, 0.30); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">GALTON<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNP/flat</sub></span> <span style="background-color: rgba(255, 165, 0, 0.66); color: white; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">OPERATORS<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNPS/compound</sub></span> <span style="background-color: transparent; color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">VS.<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NN/list</sub></span></p><p style="margin-bottom: 25px;"><span style="background-color: rgba(0, 0, 255, 0.08); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">ARGUMENTS<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNS/root</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">:<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">:/punct</sub></span> <span style="background-color: transparent; color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">THE<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">DT/det</sub></span> <span style="background-color: rgba(255, 165, 0, 0.18); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">INS<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNS/appos</sub></span> <span style="background-color: rgba(255, 165, 0, 0.25); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">AND<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">CC/cc</sub></span> <span style="background-color: rgba(255, 165, 0, 0.11); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">OUTS<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NNS/conj</sub></span> <span style="background-color: rgba(255, 165, 0, 0.10); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">OF<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">IN/case</sub></span> <span style="background-color: rgba(0, 0, 255, 0.04); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">REIFICATION<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NN/compound</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">ABSTRACT<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NN/nmod</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline- ...

# %%
for psg in get_slice_ids(id2):
    display(display_passage(psg))
# Out:
# <div style="line-height: 2.8; font-family: sans-serif; padding: 10px;"><p style="margin-bottom: 25px;"><span style="background-color: transparent; color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">That<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">DT/nsubj:outer</sub></span> <span style="background-color: rgba(0, 0, 255, 0.28); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">is<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">VBZ/cop</sub></span> <span style="background-color: rgba(0, 0, 255, 0.26); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">to<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">TO/mark</sub></span> <span style="background-color: rgba(0, 0, 255, 0.22); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">say<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">VB/root</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">,<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">,/punct</sub></span> <span style="background-color: rgba(0, 0, 255, 0.16); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">even<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">RB/advmod</sub></span> <span style="background-color: rgba(255, 165, 0, 0.10); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">in<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">IN/case</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">peace<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NN/obl</sub></span> <span style="background-color: rgba(255, 165, 0, 0.05); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">,<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">,/punct</sub></span> <span style="background-color: transparent; color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">the<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">DT/det</sub></span> <span style="background-color: transparent; color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">law<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">NN/nsubj:pass</sub></span> <span style="background-color: rgba(0, 0, 255, 0.08); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">is<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">VBZ/aux:pass</sub></span> <span style="background-color: rgba(0, 0, 255, 0.16); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">en<sub style="display: block; font-size: 0.5em; opacity: 0.7; line-height: 1;">RB/advmod</sub></span> <span style="background-color: rgba(0, 0, 255, 0.30); color: black; font-size: 1.2em; display: inline-block; text-align: center; vertical-align: top; line-height: 1.1; padding: 0 2px;">a ...

# %%
get_passage('phil/10.2307/20118780__01')
# Out:
# ANTONY GALTON OPERATORS VS.
# ----------------------------------------------------------------------------------------------------
# ARGUMENTS: THE INS AND OUTS OF REIFICATION ABSTRACT.
# ----------------------------------------------------------------------------------------------------
# INTRODUCTION Temporal Logic has been a fertile battle-ground for philosophical and technical debate, from abstruse metaphysical questions through technicalities in mathematical logic to practical issues concerning computer implementation.
# ----------------------------------------------------------------------------------------------------
# One such debate concerns the general theme of reification.
# ----------------------------------------------------------------------------------------------------
# This term, which literally means 'thing-making', refers to the use of terms in first-order logic to express concepts normally expressed using predicates, operators, or even complete propositions.
# ----------------------------------------------------------------------------------------------------
# A simple example would be replacing the formula White(x), saying that object x is white, by Colour(x, white), trans ferring the expression of whiteness from a predicate to a term.
# ----------------------------------------------------------------------------------------------------
# In temporal logic, reifica tion has been applied to such things as times, states, properties, actions, and events, which in non-reified form are expressed using predicates, formulae, tense-operators, or left implicit.
# ----------------------------------------------------------------------------------------------------
# The most favoured logical framework for this was first-order predicate calculus, and in this context, a number of researchers proposed systems which var iously reified states, actions, facts, and events.
# ----------------------------------------------------------------------------------------------------
# The debates arose between those who saw the need for such reification and those who believed that everything could be accomplished without it.
# ----------------------------------------------------------------------------------------------------
# In the context of reifying events, a further debate arose concerning reifica tion of generic event types as against individual event tokens.
# ----------------------------------------------------------------------------------------------------
# Still, we are now perhaps sufficiently far removed from their heyday for it to be timely and worthwhile to stand back and review them as a con nected piece of history.
# ----------------------------------------------------------------------------------------------------
# That is the aim of the present paper.
# ----------------------------------------------------------------------------------------------------
# SOME REMARKS ON NOTATION
# ----------------------------------------------------------------------------------------------------
# The authors discussed in this paper used a wide variety of notations.
# ----------------------------------------------------------------------------------------------------
# To facilitate comparison, it is useful to adopt some uniform con ventions, which are set out in this section.
# ----------------------------------------------------------------------------------------------------
# Formulae given by other authors will be presented in accordance with these conventions, and more often than not, this is different from their original form.
# ----------------------------------------------------------------------------------------------------
# In such cases, the notational difference is superficial: what matters is the underlying logical structures, which I have taken care to preserve in accordance with the authors' intentions.
# ----------------------------------------------------------------------------------------------------
# Where my conventions result in formulae looking very different from those of the author cited, I sometimes provide an example of that author's usage in a footnote.
# ----------------------------------------------------------------------------------------------------
# The language of most of the formulae is the first-order predi cate calculus.
# ----------------------------------------------------------------------------------------------------
# Letters or strings standing for predicates or formulae have initial capitals; function symbols, and individual constants and variables, begin with lower-case letters.
# ----------------------------------------------------------------------------------------------------
# Modal oper ators are printed in bold face (thus Prior's tense operators appear as P, F, G, and H).
# ----------------------------------------------------------------------------------------------------
# To indicate uncertainty as to an author's inten tions, I use upper-case Roman letters.
# ----------------------------------------------------------------------------------------------------
# Thus, True is a predicate or   OPERATORS VS.
# ----------------------------------------------------------------------------------------------------
# In operator-plus-argument constructions, apart from the use of truth-functional connectives to link formulae, and the t <t' construction to be introduced below, the arguments are placed in brackets after the operator, separated by commas if more than one.
# ----------------------------------------------------------------------------------------------------
# With predicates such as True, Holds, or Occurs, which relate a proposition-like entity to a time at which it is realised, I put the former entity as the first argument, the latter as the second, as e.g.
# Holds(on(a,b),t).
# ----------------------------------------------------------------------------------------------------
# This sometimes involves reversing the order of the arguments as given by the original author.
# ----------------------------------------------------------------------------------------------------
# I use p, q, etc., as terms denoting proposition-like entities (superscripted or sub scripted as the occasion demands), t for time-instants and times of unspecified character, and / for time-intervals.
# ----------------------------------------------------------------------------------------------------
# I use [t,t'] for the interval which begins at t and ends at t', ignoring any distinction between open, closed, or half-open intervals.
# ----------------------------------------------------------------------------------------------------
# I write t <t' to mean that t is earlier than t'.
# ----------------------------------------------------------------------------------------------------
# Finally, since logical expressions are throughout distinguished from the main text typographically, I have not used quotation marks when mentioning them.
# ----------------------------------------------------------------------------------------------------
# This leads to occasional anomalies, as when I refer both to 'the term f and 'the time t\ but I believe that pedanti cally restoring all the "missing" quotation marks around mentioned, as opposed to used, expressions would be detrimental to clarity.
# ----------------------------------------------------------------------------------------------------
# In the U-calculus, on the other hand, there is explicit reference to times, and a symbol T is used to relate propositions to times: in Prior's notation, Tip, where ?
# ----------------------------------------------------------------------------------------------------
# The alternative is to insist that p, q, r, cannot stand alone as for mulae.
# ----------------------------------------------------------------------------------------------------
# In this case, says Prior, we may regard them "as predicates of the instants 'at' which they are ... said to be true".
# ----------------------------------------------------------------------------------------------------
# The whole context T_p now functions as a predicate, e.g.
# P(_), so that Ttp comes out as P(t).
# ----------------------------------------------------------------------------------------------------
# If p itself has a predicate-plus-argument struc ture, e.g.
# On(a, b), then we would write this as On(a, b, t).
# ----------------------------------------------------------------------------------------------------
# The [/-calculus contains postulates governing the truth of com pound formulae formed using connectives and tense-operators.
# ----------------------------------------------------------------------------------------------------
# Using Prior's Ttp notation, the postulates governing conditionals and the G operator, for example, come out as Tt(p^q)^(Ttp-^Ttq), TtGp<+W(t<tf^Ttfp).
# ----------------------------------------------------------------------------------------------------
# How we represent these in our notation depends on which of the alternatives above we choose.
# ----------------------------------------------------------------------------------------------------
# Here the connective ?^ in P ->
# ----------------------------------------------------------------------------------------------------
# Q acts as a predicate-forming oper ator on predicates; and Prior notes that we ought strictly to use a different symbol from the propositional connective, e.g.
# OPERATORS VS.
# ----------------------------------------------------------------------------------------------------
# As noted above, if the p in Ttp is not a self-standing formula, Prior's suggestion was to regard it as a kind of predicate.
# ----------------------------------------------------------------------------------------------------
# An alter native possibility is to regard it as a term.
# ----------------------------------------------------------------------------------------------------
# In this case, T is a two place predicate, relating the 'propositional term' p to the time t.
# ----------------------------------------------------------------------------------------------------
# We write this as True(p,t).
# ----------------------------------------------------------------------------------------------------
# Since p is now a term, the connective in p-+q must be a function we could write this if(p,q) and so must the tense operator G, giving us g(p).
# ----------------------------------------------------------------------------------------------------
# The postulates now come out as: True(if(p, q), t) -> (True(p, t) -* True(q, t)), True(g(p), t) o W(t < t' -> True(p, t)).
# ----------------------------------------------------------------------------------------------------
# Since what was a 'propositional' expression has been converted into a term, the resulting system is a reified temporal logic.
# ----------------------------------------------------------------------------------------------------
# If p is a term, then it must denote some kind of entity.
# ----------------------------------------------------------------------------------------------------
# Perhaps the most obvious candidate for this is a syntactic entity, that is, a formula in some object language for which the language under dis cussion serves as a metalanguage.
# ----------------------------------------------------------------------------------------------------
# The postulates can then be seen as semantic rules.
# ----------------------------------------------------------------------------------------------------
# If the object language is ordinary Tense Logic, the metalanguage terms p and q may denote any Tense Logic formulae, say P and Q, and then the metalanguage terms if(p,q) and g(p) will denote the Tense Logic formulae P -> Q and G(P).
# ----------------------------------------------------------------------------------------------------
# The func tion symbol g denotes the function of prefixing G to a formula.
# ----------------------------------------------------------------------------------------------------
# Normally, the metalanguage in which the model theory for a logic is given is not itself expressed as a formal language.
# ----------------------------------------------------------------------------------------------------
