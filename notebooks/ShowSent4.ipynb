# %%
import sys; sys.path.append('..')
from osp import *

# %%
for id,docstr in STASH_SLICES_NLP.items():
    break
# doc=stanza.Document.from_serialized(docstr)
# sent = random.choice(doc.sentences)
txt = """
These words, it seems to me, give us a particular picture of the
essence of human language. It is this: the individual words in language
name objects—sentences are combinations of such names.——In this
picture of language we find the roots of the following idea: Every word
has a meaning. This meaning is correlated with the word. It is the
object for which the word stands.
"""

doc = get_nlp_doc(txt)
sent = doc.sentences[3]

# %%
get_sent_html(sent)
# Out:
# <span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">This<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f6f7f7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">meaning<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nsubj:pass</sub></span><span style="background-color: #f5f6f7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">is<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">aux:pass</sub></span><span style="background-color: #f7f6f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">correlated<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">root</sub></span><span style="background-color: #f9eee7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">with<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">case</sub></span><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">the<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f8f4f2; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">word<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">obl</sub></span><span style="background-color: #fae9df; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1.2; padding: 2px 4px; border-radius: 4px; margin: 1px;">.<sub style="display: block; font-size: 0.6em; display: none; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">punct</sub></span>

# %%
# render_sent_weighted(sent)

# %%
# def get_all_sent_html(sent):
#     psg = get_sent_html(sent)
#     diagram = render_sent_displacy(sent, jupyter=False)
#     return f'''
#     <div style="display: flex; flex-direction: row; gap: 10px;">
#     <div style="flex: 1; min-width: 300px;">{psg}</div><div style="flex: 1; min-width: 0; zoom: 0.5;">{diagram}</div>
#     </div>
#     '''

# %%
# pprint(render_sent_displacy(get_sent_obj("Hello"), jupyter=False))

# %%
HTML(get_doc_html(get_nlp_doc("This is the worst trash of the world. He came through the back door.")))
# Out:
# <div style="line-height: 2.8; font-family: sans-serif; padding: 10px;"><p><span style="background-color: #f0f4f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">This<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nsubj</sub></span><span style="background-color: #edf2f5; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">is<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">cop</sub></span><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">the<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f5f6f7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">worst<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">amod</sub></span><span style="background-color: #f7f6f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">trash<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">root</sub></span><span style="background-color: #f9eee7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">of<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">case</sub></span><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">the<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">world<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nmod</sub></span><span style="background-color: #fae9df; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">.<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">punct</sub></span></p><p><span style="background-color: #f0f4f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">He<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nsubj</sub></span><span style="background-color: #f7f6f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">came<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">root</sub></span><span style="background-color: #f9eee7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left ...

# %%
HTML(get_all_sent_html(sent))
# Out:
#     <div style="display: flex; flex-direction: row; gap: 10px;">
#     <div style="flex: 1; min-width: 300px;"><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">This<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f6f7f7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">meaning<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">nsubj:pass</sub></span><span style="background-color: #f5f6f7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">is<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">aux:pass</sub></span><span style="background-color: #f7f6f6; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">correlated<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">root</sub></span><span style="background-color: #f9eee7; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">with<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">case</sub></span><span style="background-color: #f7f5f4; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">the<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">det</sub></span><span style="background-color: #f8f4f2; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">word<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">obl</sub></span><span style="background-color: #fae9df; color: black; font-size: 1.2em; font-weight: normal; display: inline-block; text-align: left; vertical-align: top; line-height: 1; padding: 0 2px;">.<sub style="display: block; font-size: 0.7em; opacity: 0.9; line-height: 1; font-weight: normal; padding: 2px; font-family: monospace;">punct</sub></span></div><div style="flex: 1; min-width: 0; zoom: 0.5;"><svg class="displacy" direction="ltr" height="487.0" id="04d4cee0dc5c443f82bb7b733ae48dc6-0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr" width="1450" xml:lang="en" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="50">This</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #ecf2f5; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="50">DT</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="225">meaning</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #f8f3f0; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="225">NN</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="400">is</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #f7f6f6; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="400">VBZ</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="575">correlated</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #f7b799; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="575">VBN</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="750">with</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #fac8af; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="750">IN</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="925">the</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #ecf2f5; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="925">DT</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="1100">word</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #f8f3f0; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="1100">NN</tspan>
# </text>
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# <tspan class="displacy-word" fill="currentColor" style="font-size: 1.5em;" x="1275">.</tspan>
# <tspan class="displacy-tag" dy="2em" fill="black" style="paint-order: stroke fill; stroke: #f0f4f6; stroke-width: 1em; stroke-linecap: round; stroke-linejoin: round; font-size: 1.5em;" x="1275">.</tspan>
# </text>
# <g class="displacy-arrow">
# <path class="displacy-arc" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" id="arrow-04d4cee0dc5c443f82bb7b733ae48dc6-0-0" stroke="currentColor" stroke-width="2px"></path>
# <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# <textpath class="displacy-label" fill="black" side="left" startoffset="50%" style="paint-order: stroke fill; stroke: #f8bb9e; stroke-width: .3em; font-size: 1.5em;" text-anchor="middle" xlink:href="#arrow-04d4cee0dc5c443f82bb7b733ae48dc6-0-0">det</textpath>
# </text>
# <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"></path>
# </g>
# <g class="displacy-arrow">
# <path class="displacy-arc" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" id="arrow-04d4cee0dc5c443f82bb7b733ae48dc6-0-1" stroke="currentColor" stroke-width="2px"></path>
# <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# <textpath class="displacy-label" fill="black" side="left" startoffset="50%" style="paint-order: stroke fill; stroke: #f7f6f6; stroke-width: .3em; font-size: 1.5em;" text-anchor="middle" xlink:href="#arrow-04d4cee0dc5c443f82bb7b733ae48dc6-0-1">nsubj:pass</textpath>
# </text>
# <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"></path>
# </g>
# <g class="displacy-arrow">
# <path class="displacy-arc" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" id="arrow-04d4cee0dc5c443f82bb7b733ae48dc6-0-2" stroke="currentColor" stroke-width="2px"></path>
# <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# <textpath class="displacy-label" fill="black" si
