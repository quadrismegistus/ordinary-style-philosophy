# %%
import sys; sys.path.append('..')
from osp import *
pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 20

# %%
df_preds, df_feats, d_models = get_preds_feats(COMPARISONS[:1], feat_types=['deprel'], num_runs=1, verbose=True)
# Out:
# ## 1900-1925 Philosophy vs 1900-1925 Literature
#   0%|          | 0/1 [00:00<?, ?it/s]
# Balanced data: 752 samples per target
# Running 10-fold Cross-Validation on 1504 samples...
# 100%|██████████| 1/1 [00:07<00:00,  7.17s/it]
# Classifier Results (10-fold CV):
# Accuracy: 0.8504
#               precision    recall  f1-score   support
#
#   Literature       0.86      0.84      0.85       752
#   Philosophy       0.84      0.86      0.85       752
#
#     accuracy                           0.85      1504
#    macro avg       0.85      0.85      0.85      1504
# weighted avg       0.85      0.85      0.85      1504

# %%
df_feats['weight_abs'] = df_feats['weight'].abs()
df_feats.groupby('feat_type').mean(numeric_only=True).T
# Out:
# feat_type               deprel        pos
# weight                0.156556  -0.132470
# run                   0.000000   0.000000
# score_mean1          20.830727  22.459648
# score_mean2          20.803444  22.414911
# score_z1             20.831514  22.473705
# score_z2             20.803444  22.414911
# score_mean_diff       0.027283   0.044737
# score_mean_diff_abs   2.247110   4.001656
# score_mean_diff_pct        inf  -0.109486
# score_mean_div             inf   0.890514
# score_mean_div_abs         inf   0.890514
# score_z_diff          0.028071   0.058794
# score_z_diff_abs      2.304647   4.022303
# score_z_diff_pct           inf  -0.106049
# score_z_div                inf   0.893951
# score_z_div_abs            inf   0.893951
# weight_abs            0.211967   0.169428

# %%
stopxx

# %%
# COMPARISONS

# %%
get_all_feats()
# Out:
#                            sent_height  sent_num_words_in_dependent_clauses  \
# id
# phil/10.2307/20111773__02    -0.390519                             1.289891
# phil/10.2307/2379466__05      0.505629                             1.583164
# lit/468313__05               -0.057800                            -1.719735
# lit/509517__01               -1.455944                            -0.562000
# phil/10.2307/20140633__02     1.184079                             1.028434
# ...                                ...                                  ...
# lit/30031939__01             -0.658682                            -0.668491
# phil/10.2307/2025409__04      0.481351                             0.784142
# phil/10.2307/2953730__03      1.122135                             1.146417
# lit/468421__06               -1.064896                            -0.278295
# phil/10.2307/2185617__06      0.865627                             0.044130
#
#                            sent_num_words_in_independent_clauses  \
# id
# phil/10.2307/20111773__02                              -1.289891
# phil/10.2307/2379466__05                               -1.583164
# lit/468313__05                                          1.719735
# lit/509517__01                                          0.562000
# phil/10.2307/20140633__02                              -1.028434
# ...                                                          ...
# lit/30031939__01                                        0.668491
# phil/10.2307/2025409__04                               -0.784142
# phil/10.2307/2953730__03                               -1.146417
# lit/468421__06                                          0.278295
# phil/10.2307/2185617__06                               -0.044130
#
#                            sent_num_independent_clauses  \
# id
# phil/10.2307/20111773__02                     -0.438993
# phil/10.2307/2379466__05                      -0.492482
# lit/468313__05                                -0.290963
# lit/509517__01                                -1.981948
# phil/10.2307/20140633__02                     -0.616117
# ...                                                 ...
# lit/30031939__01                              -1.020335
# phil/10.2307/2025409__04                       0.266945
# phil/10.2307/2953730__03                      -0.129505
# lit/468421__06                                 0.217638
# phil/10.2307/2185617__06                       1.067236
#
#                            sent_num_dependent_clauses    pos_IN    pos_NN  \
# id
# phil/10.2307/20111773__02                    1.207121 -0.070315 -1.706248
# phil/10.2307/2379466__05                     1.049130  0.117227 -0.279952
# phil/10.2307/2025409__04       -0.169213        -0.026484 -0.06553 -0.033107
# phil/10.2307/2953730__03       -0.169213        -0.026484 -0.06553 -0.033107
# lit/468421__06                 -0.169213        -0.026484 -0.06553 -0.033107
# phil/10.2307/2185617__06        5.909973        -0.026484 -0.06553 -0.033107
#
# [33666 rows x 97 columns]

# %%
# df_preds, df_feats, d_models = get_preds_feats(_force=True)
df_preds, df_feats, d_models = get_preds_feats(num_runs=1)
# Out:
# ## 1900-1925 Philosophy vs 1900-1925 Literature
# getting target for cv data: 100%|██████████| 33666/33666 [00:00<00:00, 40133.14it/s]
# getting target for cv data: 100%|██████████| 1382/1382 [00:00<00:00, 43247.02it/s]
# getting target for cv data: 100%|██████████| 752/752 [00:00<00:00, 42145.36it/s]
# Index(['sent_height', 'sent_num_words_in_dependent_clauses',
#        'sent_num_words_in_independent_clauses', 'sent_num_independent_clauses',
#        'sent_num_dependent_clauses', 'pos_IN', 'pos_NN', 'pos_JJ', 'pos_DT',
#        'pos_,', 'pos_RB', 'pos_VBZ', 'pos_PRP', 'pos_NNS', 'pos_CC', 'pos_.',
#        'pos_VBN', 'pos_VB', 'pos_VBP', 'pos_NNP', 'pos_WDT', 'pos_VBG',
#        'pos_MD', 'pos_CD', 'pos_TO', 'pos_PRP$', 'pos_EX', 'pos_POS', 'pos_WP',
#        'pos_-LRB-', 'pos_-RRB-', 'pos_VBD', 'pos_:', 'pos_FW', 'pos_RP',
#        'pos_WRB', 'pos_HYPH', 'pos_NNPS', 'deprel_punct', 'deprel_case',
#        'deprel_det', 'deprel_nsubj', 'deprel_amod', 'deprel_advmod',
#        'deprel_mark', 'deprel_obl', 'deprel_nmod', 'deprel_cc', 'deprel_root',
#        'deprel_conj', 'deprel_cop', 'deprel_advcl', 'deprel_obj',
#        'deprel_acl:relcl', 'deprel_aux:pass', 'deprel_ccomp', 'deprel_aux',
#        'deprel_nsubj:pass', 'deprel_xcomp', 'deprel_nmod:poss', 'deprel_expl',
#        'deprel_acl', 'deprel_fixed', 'deprel_compound', 'deprel_nummod',
#        'deprel_appos', 'deprel_parataxis', 'deprel_obl:agent',
#        'deprel_compound:prt', 'deprel_dep', 'deprel_nsubj:outer',
#        'deprel_csubj', 'deprel_obl:unmarked', 'deprel_nmod:unmarked',
#        'deprel_cc:preconj', 'deprel_dislocated', 'pos_JJS', 'pos_RBR',
#        'pos_PDT', 'pos_JJR', 'deprel_det:predet', 'deprel_iobj',
#        'deprel_csubj:pass', 'pos_RBS', 'deprel_advcl:relcl', 'pos_UH',
#        'pos_WP$', 'deprel_discourse', 'deprel_vocative', 'pos_NFP',
#        'deprel_reparandum', 'deprel_csubj:outer', 'pos_SYM', 'deprel_orphan',
#        'deprel_goeswith', 'pos_AFX', 'pos_GW', '_target'],
#       dtype='object')
# 100%|██████████| 1/1 [00:08<00:00,  8.83s/it]
# getting target for cv data: 100%|██████████| 33666/33666 [00:00<00:00, 37950.67it/s]
# getting target for cv data: 100%|██████████| 1382/1382 [00:00<00:00, 39813.51it/s]
# getting target for cv data: 100%|██████████| 752/752 [00:00<00:00, 42107.10it/s]
# getting target for cv data: 100%|██████████| 33666/33666 [00:00<00:00, 39543.92it/s]
# getting target for cv data: 100%|██████████| 1382/1382 [00:00<00:00, 37423.27it/s]
# getting target for cv data: 100%|██████████| 752/752 [00:00<00:00, 39847.35it/s]
# ## 1925-1950 Philosophy vs 1925-1950 Literature
# getting target for cv data: 100%|██████████| 33666/33666 [00:00<00:00, 41019.38it/s]
# getting target for cv data: 100%|██████████| 2250/2250 [00:00<00:00, 42791.26it/s]
# getting target for cv data: 100%|██████████| 1359/1359 [00:00<00:00, 42415.57it/s]
# Index(['sent_height', 'sent_num_words_in_dependent_clauses',
#        'sent_num_words_in_independent_clauses', 'sent_num_independent_clauses',
#        'sent_num_dependent_clauses', 'pos_IN', 'pos_NN', 'pos_JJ', 'pos_DT',
#        'pos_,', 'pos_RB', 'pos_VBZ', 'pos_PRP', 'pos_NNS', 'pos_CC', 'pos_.',
#        'pos_VBN', 'pos_VB', 'pos_VBP', 'pos_NNP', 'pos_WDT', 'pos_VBG',
#        'pos_MD', 'pos_CD', 'pos_TO', 'pos_PRP$', 'pos_EX', 'pos_POS', 'pos_WP',
#        'pos_-LRB-', 'pos_-RRB-', 'pos_VBD', 'pos_:', 'pos_FW', 'pos_RP',
#        'pos_WRB', 'pos_HYPH', 'pos_NNPS', 'deprel_punct', 'deprel_case',
#        'deprel_det', 'deprel_nsubj', 'deprel_amod', 'deprel_advmod',
#        'deprel_mark', 'deprel_obl', 'deprel_nmod', 'deprel_cc', 'deprel_root',
#        'deprel_conj', 'deprel_cop', 'deprel_advcl', 'deprel_obj',
#        'deprel_acl:relcl', 'deprel_aux:pass', 'deprel_ccomp', 'deprel_aux',
#        'deprel_nsubj:pass', 'deprel_xcomp', 'deprel_nmod:poss', 'deprel_expl',
#        'deprel_acl', 'deprel_fixed', 'deprel_compound', 'deprel_nummod',
#        'deprel_appos', 'deprel_parataxis', 'deprel_obl:agent',
#        'deprel_compound:prt', 'deprel_dep', 'deprel_nsubj:outer',
#        'deprel_csubj', 'deprel_obl:unmarked', 'deprel_nmod:unmarked',
#        'deprel_cc:preconj', 'deprel_dislocated', 'pos_JJS', 'pos_RBR',
#        'pos_PDT', 'pos_JJR', 'deprel_det:predet', 'deprel_iobj',
#        'deprel_csubj:pass', 'pos_RBS', 'deprel_advcl:relcl', 'pos_UH',
#        'pos_WP$', 'deprel_discourse', 'deprel_vocative', 'pos_NFP',
#        'deprel_reparandum', 'deprel_csubj:outer', 'pos_SYM', 'deprel_orphan',
#        'deprel_goeswith', 'pos_AFX', 'pos_GW', '_target'],
#       dtype='object')
# 100%|██████████| 1/1 [00:09<00:00,  9.17s/it]
# getting target for cv data:  24%|██▎       | 7969/33666 [00:00<00:00, 39955.18it/s]

# %%
# pd.options.display.max_rows = 10

df_preds[df_preds.predict_type=="unseen"].groupby(['true_label','comparison']).size()
# Out:
# true_label  comparison
# Literature  1900-1925 Philosophy vs 1900-1925 Literature    104540
#             1925-1950 Philosophy vs 1925-1950 Literature     98470
#             1950-1975 Philosophy vs 1950-1975 Literature     89900
#             1975-2000 Philosophy vs 1975-2000 Literature     74370
#             2000-2025 Philosophy vs 2000-2025 Literature     80960
# Philosophy  1900-1925 Philosophy vs 1900-1925 Literature    217080
#             1925-1950 Philosophy vs 1925-1950 Literature    211010
#             1950-1975 Philosophy vs 1950-1975 Literature    202440
# phil/10.2307/2953730__03         0.982909  Literature / Philosophy
# lit/468421__06                   0.970832  Literature / Philosophy
# phil/10.2307/2185617__06         0.580396  Literature / Philosophy
#
#                           confidence  correct  accuracy  support  run  \
# id
# lit/458348__02              0.908500        1    0.9155   2000.0    0
# lit/457860__02              0.974676        1    0.9155   2000.0    0
# lit/459316__04              0.999719        1    0.9155   2000.0    0
# ...                              ...      ...       ...      ...  ...
# phil/10.2307/2953730__03         NaN        0       NaN      NaN    9
# lit/468421__06                   NaN        0       NaN      NaN    9
# phil/10.2307/2185617__06         NaN        0       NaN      NaN    9
#
#                          predict_type  \
# id
# lit/458348__02                     cv
# lit/457860__02                     cv
# lit/459316__04                     cv
# ...                               ...
# phil/10.2307/2953730__03       unseen
# lit/468421__06                 unseen
# phil/10.2307/2185617__06       unseen
#
#                                                             comparison
# id
# lit/458348__02            1925-1950 Philosophy vs 1925-1950 Literature
# lit/457860__02            1925-1950 Philosophy vs 1925-1950 Literature
# lit/459316__04            1925-1950 Philosophy vs 1925-1950 Literature
# ...                                                                ...
# phil/10.2307/2953730__03  2000-2025 Philosophy vs 2000-2025 Literature
# lit/468421__06            2000-2025 Philosophy vs 2000-2025 Literature
# phil/10.2307/2185617__06  2000-2025 Philosophy vs 2000-2025 Literature
#
# [1132200 rows x 12 columns]

# %%
# df_preds, df_feats, d_models = classify_then_predict_comparisons(
#     COMPARISONS,
#     num_runs=10,
#     sample_size=1000,
#     feat_n=50,
#     feat_n_egs=10,
#     verbose=False,
#     return_models=True,
#     normalize=False,
# )

# df_preds, df_feats, d_models = get_preds_feats()

# %%
# df_preds

# %%
df_preds, df_feats, d_models = get_preds_feats()

# %%
df_feats[['feature','weight','score_mean1','score_z1']].sort_values('weight',ascending=False).head(10)
# Out:
#               feature    weight  score_mean1   score_z1
# 58             pos_FW  0.924665     0.821637   0.827107
# 58             pos_FW  0.851065     0.980653   0.995061
# 58             pos_FW  0.511805     0.907464   0.939736
# ..                ...       ...          ...        ...
# 44  deprel_reparandum  0.262088     0.321187   0.330648
# 23   deprel_discourse  0.251378     0.934904   0.950481
# 54             pos_CC  0.225784    33.694057  33.634660
#
# [10 rows x 4 columns]

# %%
newtext= """By a `denoting phrase' I mean a phrase such as any one of the following: a man, some man, any man, every man, all men, the present King of England, the presenting King of France, the center of mass of the solar system at the first instant of the twentieth century, the revolution of the earth round the sun, the revolution of the sun round the earth. Thus a phrase is denoting solely in virtue of its form. We may distinguish three cases: (1) A phrase may be denoting, and yet not denote anything; e.g., `the present King of France'. (2) A phrase may denote one definite object; e.g., `the present King of England' denotes a certain man. (3) A phrase may denote ambiguously; e.g. `a man' denotes not many men, but an ambiguous man. The interpretation of such phrases is a matter of considerably difficulty; indeed, it is very hard to frame any theory not susceptible of formal refutation. All the difficulties with which I am acquainted are met, so far as I can discover, by the theory which I am about to explain."""

doc = get_nlp_doc(newtext)

# %%
df_new_preds, df_new_feats = get_new_preds_feats(doc)

# %%
df_new_feats.groupby('feature').mean(numeric_only=True)[['weight','score_mean1','score_mean2','score_mean3','score_mean_div_3-1','score_mean_div_3-2']].sort_values('score_mean_div_3-2',ascending=True).sample(5)
# Out:
#                                          weight  score_mean1  score_mean2  \
# feature
# deprel_expl                           -0.076533     5.746964     3.089669
# pos_FW                                 0.614853     0.853004     0.260762
# sent_num_words_in_independent_clauses  0.007595   374.365766   526.388508
# deprel_csubj                          -0.104341     2.359387     1.337220
# pos_JJS                               -0.080529     1.355949     1.368312
#
#                                        score_mean3  score_mean_div_3-1  \
# feature
# deprel_expl                               4.385965            0.764007
# pos_FW                                   13.157895           15.666947
# sent_num_words_in_independent_clauses   934.210526            2.508512
# deprel_csubj                              4.385965            1.881202
# pos_JJS                                   0.000000            0.000000
#
#                                        score_mean_div_3-2
# feature
# deprel_expl                                      1.463939
# pos_FW                                          59.372368
# sent_num_words_in_independent_clauses            1.777253
# deprel_csubj                                     3.298811
# pos_JJS                                          0.000000

# %%
df_new_preds.mean(numeric_only=True)
# Out:
# run      4.50000
# prob1    0.22055
# prob2    0.77945
# dtype: float64

# %%
df_preds
# Out:
#                           true_label       pred_label                prob1  \
# id
# lit/3716491__04           Literature       Philosophy  0.49144014963593696
# lit/2871701__01           Literature       Literature   0.9991263267257862
# lit/457453__01            Literature       Literature   0.9974224957261134
# ...                              ...              ...                  ...
# phil/10.2307/2953730__03  Philosophy  prob_Philosophy                  nan
# lit/468421__06            Literature  prob_Philosophy                  nan
# phil/10.2307/2185617__06  Philosophy  prob_Philosophy                  nan
#
#                                           prob2               test_label  \
# id
# lit/3716491__04               0.508559850364063  Literature / Philosophy
# lit/2871701__01            0.000873673274213794  Literature / Philosophy
# lit/457453__01            0.0025775042738865593  Literature / Philosophy
# ...                                         ...                      ...
# phil/10.2307/2953730__03                    nan  Literature / Philosophy
# lit/468421__06                              nan  Literature / Philosophy
# phil/10.2307/2185617__06                    nan  Literature / Philosophy
#
#                                   confidence  correct accuracy support  run  \
# id
# lit/3716491__04            0.508559850364063        0   0.9145  2000.0    0
# lit/2871701__01           0.9991263267257862        1   0.9145  2000.0    0
# lit/457453__01            0.9974224957261134        1   0.9145  2000.0    0
# ...                                      ...      ...      ...     ...  ...
# phil/10.2307/2953730__03                 nan        0      nan     nan    9
# lit/468421__06                           nan        0      nan     nan    9
# phil/10.2307/2185617__06                 nan        0      nan     nan    9
#
#                          predict_type       prob_Literature  \
# id
# lit/3716491__04                    cv                   nan
# lit/2871701__01                    cv                   nan
# lit/457453__01                     cv                   nan
# ...                               ...                   ...
# phil/10.2307/2953730__03       unseen  0.012841101948878997
# lit/468421__06                 unseen    0.1272485323519187
# phil/10.2307/2185617__06       unseen    0.3808832762297668
#
#                              prob_Philosophy  \
# id
# lit/3716491__04                          nan
# lit/2871701__01                          nan
# lit/457453__01                           nan
# ...                                      ...
# phil/10.2307/2953730__03   0.987158898051121
# lit/468421__06            0.8727514676480813
# phil/10.2307/2185617__06  0.6191167237702332
#
#                                                             comparison
# id
# lit/3716491__04           1925-1950 Philosophy vs 1925-1950 Literature
# lit/2871701__01           1925-1950 Philosophy vs 1925-1950 Literature
# lit/457453__01            1925-1950 Philosophy vs 1925-1950 Literature
# ...                                                                ...
# phil/10.2307/2953730__03  2000-2025 Philosophy vs 2000-2025 Literature
# lit/468421__06            2000-2025 Philosophy vs 2000-2025 Literature
# phil/10.2307/2185617__06  2000-2025 Philosophy vs 2000-2025 Literature
#
# [1132200 rows x 14 columns]
