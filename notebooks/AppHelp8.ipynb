# %%
import streamlit as st
from streamlit_jupyter import StreamlitPatcher, tqdm
StreamlitPatcher().jupyter()  # register streamlit with jupyter-compatible wrappers
import sys; sys.path.append('..')
from osp import *
pd.options.display.max_colwidth = 200
pd.options.display.max_rows = 20

# %%
groups_train = COMPARISONS[0]

# %%
# get_balanced_slice_sample(groups_train)
dfx = get_balanced_slice_sample_feats(groups_train, with_diff_rows=True)
# dfx
# Out:
# Loading features for 1504 slices...
# Filtering valid slices...
# Aggregating feature statistics...
# Computing difference rows...
# Computing difference rows: 100%|██████████| 131/131 [00:00<00:00, 3567.37it/s]

# %%
dfx
# Out:
#                                                                z        raw  \
# feat       target
# pos_NNP    1900-1925 Literature                         1.141156  64.052067
#            1900-1925 Philosophy                        -0.540565  16.122058
#            1900-1925 Philosophy - 1900-1925 Literature -1.681720 -47.930009
# ttr_OTHER  1900-1925 Literature                         1.085644   0.165395
#            1900-1925 Philosophy                        -0.345932   0.132457
# ...                                                          ...        ...
# phrase_NAC 1900-1925 Literature                        -0.012079   0.000000
#            1900-1925 Philosophy                        -0.012079   0.000000
# phrase_$   1900-1925 Philosophy - 1900-1925 Literature  0.000000   0.000000
#            1900-1925 Literature                        -0.009382   0.000000
#            1900-1925 Philosophy                        -0.009382   0.000000
#
#                                                            z_abs  feat_rank
# feat       target
# pos_NNP    1900-1925 Literature                         1.141156          1
#            1900-1925 Philosophy                         0.540565          1
#            1900-1925 Philosophy - 1900-1925 Literature  1.681720          1
# ttr_OTHER  1900-1925 Literature                         1.085644          2
#            1900-1925 Philosophy                         0.345932          2
# ...                                                          ...        ...
# phrase_NAC 1900-1925 Literature                         0.012079        130
#            1900-1925 Philosophy                         0.012079        130
# phrase_$   1900-1925 Philosophy - 1900-1925 Literature  0.000000        131
#            1900-1925 Literature                         0.009382        131
#            1900-1925 Philosophy                         0.009382        131
#
# [393 rows x 4 columns]
