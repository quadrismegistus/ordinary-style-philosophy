# %%
import sys; sys.path.append('..')
from osp import *
pd.options.display.max_colwidth = None
pd.options.display.max_rows = 20

# %%
df_meta = get_corpus_metadata()
ids_phil = df_meta.query('discipline == "Philosophy"').index.tolist()
ids_lit = df_meta.query('discipline == "Literature"').index.tolist()
len(ids_phil), len(ids_lit)
# Out:
# (32277, 25343)

# %%
import numpy as np

groups = [
    ('Philosophy', ids_phil),
    ('Literature', ids_lit),
]

def get_mdw_pos(ids1, ids2, name1="Group 1", name2="Group 2", feat_n=FEAT_N, feat_min_count=FEAT_MIN_COUNT, incl_deprel=True, incl_pos=True, feat_n_egs=FEAT_N//2, rename_cols=False):
    df_pos_grp1 = get_pos_counts(ids1, incl_deprel=incl_deprel, incl_pos=incl_pos)
    df_pos_grp2 = get_pos_counts(ids2, incl_deprel=incl_deprel, incl_pos=incl_pos)

    words_grp1 = get_pos_word_counts(ids1)
    words_grp2 = get_pos_word_counts(ids2)

    egs_grp1 = get_pos_word_egs(ids1)
    egs_grp2 = get_pos_word_egs(ids2)


    df_pos = pd.concat([df_pos_grp1.assign(_target=name1), df_pos_grp2.assign(_target=name2)])
    fisher_results = fisher_test_pos(df_pos, target_col='_target', g1=name1, g2=name2)

    df_means = df_pos.groupby('_target').mean()
    feat2grp2mean = df_means.to_dict()
    df_sums = df_pos.groupby('_target').sum()

    ld = []
    feat1 = None

    colname1 = f'1 ({name1})'
    colname2 = f'2 ({name2})'

    for feat in feat2grp2mean:
        feat_d = {'feat':feat}
        grp2mean = feat2grp2mean[feat]
        
        feat_d[f'fpk1'] = grp2mean[name1]
        feat_d[f'fpk2'] = grp2mean[name2]
        feat_d[f'top1'] = get_egs(words_grp1[feat], n=feat_n, min_count=feat_min_count)
        feat_d[f'top2'] = get_egs(words_grp2[feat], n=feat_n, min_count=feat_min_count)

        feat_d[f'egs1'] = get_egs(words_grp1[feat], n=feat_n_egs, min_count=feat_min_count, word2eg=egs_grp1[feat])
        feat_d[f'egs2'] = get_egs(words_grp2[feat], n=feat_n_egs, min_count=feat_min_count, word2eg=egs_grp2[feat])
        # feat_d['total'] = feat_d[g1] + feat_d[g2]
        
        # feat1 = feat
        ld.append(feat_d)
    odf = pd.DataFrame(ld).dropna().set_index('feat')
    odf['fpk1-fpk2'] = odf[f'fpk1'] - odf[f'fpk2']
    odf['fpk1/fpk2'] = odf[f'fpk1'] / odf[f'fpk2']
    odf = fisher_results.join(odf).sort_values('p_value', ascending=True)
    odf['odds_ratio_log'] = np.log10(odf['odds_ratio'])
    odf['odds_ratio_log_abs'] = np.abs(odf['odds_ratio_log'])
    odf['feat_desc'] = [FEAT2DESC.get(feat,'?') for feat in odf.index]
    odf = odf.reset_index()

    def desc_result(row):
        if row.odds_ratio > 1:
            return f'{row.feat_desc}s are {row.odds_ratio:.1f}x more common in {name1} than {name2}.'
        else:
            return f'{row.feat_desc}s are {1/row.odds_ratio if row.odds_ratio != 0 else 0:.1f}x more common in {name2} than {name1}.'
    
    odf = odf.sort_values('odds_ratio_log_abs', ascending=False)
    odf['mdw_rank'] = [i+1 for i in range(len(odf))]

    odf = odf.sort_values('odds_ratio', ascending=False)
    odf['mdw1_rank'] = [i+1 for i in range(len(odf))]
    odf = odf.sort_values('odds_ratio', ascending=True)
    odf['mdw2_rank'] = [i+1 for i in range(len(odf))]

    odf['result_desc'] = odf.apply(desc_result, axis=1)
    odf = odf[[
        'feat', 
        'feat_desc', 
        'result_desc',
        
        'fpk1','fpk2',
        'odds_ratio',
        # 'fpk1-fpk2',
        # 'fpk1/fpk2',
        'sum1','sum2',
        'sig','top1','top2','egs1','egs2',
        'mdw_rank',
        'mdw1_rank',
        'mdw2_rank',
        ]]
    # odf = odf.drop(columns=['fpk1','fpk2','fpk1-fpk2'])
    # odf = odf[[c for c in odf.columns if c not in end_cols] + end_cols]
    odf = odf.rename(columns={
        'sum1': f'{name1} (#)',
        'sum2': f'{name2} (#)',
        'pct1': f'{name1} (%)',
        'pct2': f'{name2} (%)',
        'fpk1': f'{name1} (#/k)',
        'fpk2': f'{name2} (#/k)',
        'odds_ratio': f'{name1} / {name2} (OR)',
        'sig': 'Significance',
        'top1': f'{name1} (top {feat_n})',
        'top2': f'{name2} (top {feat_n})',
        'egs1': f'{name1} (examples)',
        'egs2': f'{name2} (examples)',
        'fpk1-fpk2': f'{name1} - {name2} (#/k)',
    }) if rename_cols else odf
    return odf.set_index(['feat','feat_desc','result_desc']).sort_values('mdw_rank').dropna()

# %%
odf = get_mdw_pos(ids_phil, ids_lit, 'Philosophy', 'Literature', feat_n=25, feat_min_count=1, incl_deprel=True, feat_n_egs=3,rename_cols=False).round(2).query('sig=="***"')

# %%
odf.sort_values('mdw1_rank').head(10)
# Out:
#                                                                                                                   fpk1  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.         0.41
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                        0.02
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.  0.36
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.             0.93
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                   0.37
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.        2.94
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                5.75
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                        2.32
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       9.75
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          2.47
#
#                                                                                                                   fpk2  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.         0.09
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                        0.01
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.  0.10
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.             0.27
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                   0.14
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.        1.52
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                3.05
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                        1.27
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       5.37
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          1.40
#
#                                                                                                                   odds_ratio  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.               4.46
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                              3.93
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.        3.68
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                   3.40
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                         2.71
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.              1.94
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                      1.89
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                              1.83
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.             1.82
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.                1.76
#
#                                                                                                                    sum1  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.          2368
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                          125
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.   2077
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.              5396
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                    2174
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.        17156
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                33481
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                        13504
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       56780
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          14405
#
#                                                                                                                    sum2  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.           267
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                           16
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.    284
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.               798
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                     403
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.         4441
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                 8928
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                         3710
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       15720
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.           4107
#
#                                                                                                                   sig  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.         ***
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                        ***
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.  ***
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.             ***
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                   ***
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.        ***
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                ***
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                        ***
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       ***
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          ***
#
#                                                                                                                                                                                                                                                                       top1  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                                                                          ii a i iii v vi b k iv vii xxxi viii xliv xlvi xxxv xxi xxv xiv d xxvi xi xxxix bn ^ £)
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                                                                                                                                                              £ $ \( £- }( <£ t(
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.                                                                                            * { | ~ -> - · > ^ -* \ ** /? /. >. := _ -< => ̄ = *) *( ?> >(
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                                                                                             i.e. e.g. etc i.e etc. e.g cf eds. pp. c. viz. cf. ed. , esp. i. nt soc.
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                                                                                                          = / + { ̄ \ -> \( => // ^ /- ~ /( ^( |= x +( *) := \- /a -+ /\ +/
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.                                                                                                                                                           there
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                                                                                                                                                        there it neither
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                        what it that point this problem reason question way idea aim one all answer claim purpose fact thing view difference goal conclusion which task argument
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.                       is have has are true be know what do possible make one ought exist false exists case made makes had wrong justified necessary take right
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.               say see have think having make suppose note do doing believe is take know find knowing give consider show assume imagine hold seeing understand use
#
#                                                                                                                                                                                                                                                                                 top2  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                                                                      ii a vi v iii i viii iv vii xi xli xii xxxvi xxviii xxii xxxviii xxxvii xxxi xviii k lviii xliii lxvi
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                                                                                                                                                                                    £ $ £–
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.                                                                                                  * - | { > ~ z ^ [. ;- :: *** /. >. _ '( .t. ~. _. -- -> :) :; ; ='
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                                                                          etc e.g. etc. i.e. pp. i.e , ed. e.g c. so cf. v. cf esp. eds. i. ca. ibid. eng. nt viz. &c. str. mar
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                                                                                                                                                            / = + – .is _. ^ .e *s o/
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.                                                                                                                                                                     there
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                                                                                                                                                                  it there neither
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                                     it what that point this one which purpose way reason question problem thing all fact aim effect result function answer we whatever task he difference
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.                                                  is have had has made are was come what one read become found used make be take do know seems see find came written seen
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          say see find have make note read think had assume writing imagine understand do consider know recognize suppose give made take suggest distinguish explain believe
#
#                                                                                                                                                                                                                                    egs1  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                           "behind criterion (II" "raising here are (A) how the identity" "satisfaction of (I) is not only an"
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                                 "sublanguage L of $ £ with a notion of" "sublanguage L of $ £ with a notion" "A) then if \(B / A) is broken"
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.                                "G < / >(*), we call physical" "Axiom P { ext (S)   S G" "to equal P(| E), in parallel"
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                                             "modern physics, I.E., classical mechanics" "E.G. I expect that I" "the present, ETC"
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                                      "predicates, £ = { E, F,. Individual" "of sentences < / >v that are verifiable" "p (E) + p(F), lj"
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.                                                                                  "foreseeable bound, THERE is no reason why"
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                                        "in time t, THERE will be some set" "IT is not satisfactory" "But NEITHER vindicates realism"
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                                                                         "WHAT this amounts to" "IT is for the patient" "THAT toward the end"
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.       "asserts that there IS a particular set" "indispensable we HAVE no choice but to" "our procedure HAS to cope with an"
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.            "thing simply to SAY that philosophers" "important to SEE that in the fist" "expedient to HAVE any relations which"
#
#                                                                                                                                                                                                                                         egs2  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                                                                             "II fut tout puissant" "Items : (A) The issue of" "VI"
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                                 "home with a £ stove and a collection" "assumes a base * $ en@ get, grasp" "five guineas (£– £ in current buying"
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.                                                      "X *" "OF MORE - AND - LESS : LETTER" "la muerte, | la eternajuventud"
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                                     "CINEMATIC MUSICAL ETC" "the sequenced (E.G., comic strip" "the merchants, ETC., it is impossible"
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                                                  "for my part, / See reasons and" "protocomes (= admiral or provost" "human], [+ concrete],"
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.                                                                                               "observe that THERE is not one but"
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                                                                   "IT is precisely for" "THERE are, of course" "NEITHER is it sufficient"
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                         "IT is, too, so closely" "observed : Now, WHAT specifically defines" "sublimation affected; THAT is, whether sublimation"
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.                "observe that there IS not one but two" "Kleist would HAVE her appear as the" "iconography, HAD a language often"
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.          "appropriate to SAY that they retreat" "justifiable to SEE them as the present" "remarkable that we FIND embedded in this"
#
#                                                                                                                   mdw_rank  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                1
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                               2
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.         4
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                    5
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                          9
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.              14
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                      15
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                              17
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.             18
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.                19
#
#                                                                                                                   mdw1_rank  \
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                 1
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                                2
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.          3
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                     4
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                           6
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.                7
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                        8
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                                9
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.              10
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.                 11
#
#                                                                                                                   mdw2_rank
# feat        feat_desc               result_desc
# LS          List item marker        List item markers are 4.5x more common in Philosophy than Literature.                98
# $           ?                       ?s are 3.9x more common in Philosophy than Literature.                               97
# NFP         Superfluous punctuation Superfluous punctuations are 3.7x more common in Philosophy than Literature.         96
# FW          Foreign word            Foreign words are 3.4x more common in Philosophy than Literature.                    95
# SYM         Symbol                  Symbols are 2.7x more common in Philosophy than Literature.                          93
# EX          Existential there       Existential theres are 1.9x more common in Philosophy than Literature.               92
# expl        Expletive               Expletives are 1.9x more common in Philosophy than Literature.                       91
# nsubj:outer ?                       ?s are 1.8x more common in Philosophy than Literature.                               90
# ccomp       Clausal complement      Clausal complements are 1.8x more common in Philosophy than Literature.              89
# csubj       Clausal subject         Clausal subjects are 1.8x more common in Philosophy than Literature.                 88

# %%
odf.sort_values('mdw2_rank').head(5)
# Out:
#                                                                                                             fpk1  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.     0.58
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                       0.17
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.        5.84
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  18.43
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                       0.15
#
#                                                                                                             fpk2  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.     2.24
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                       0.48
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.       15.46
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  44.55
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                       0.34
#
#                                                                                                            odds_ratio  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.          0.26
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                            0.36
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.             0.38
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.        0.41
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                            0.44
#
#                                                                                                              sum1  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.      3387
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                        1009
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.        34021
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  107358
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                         863
#
#                                                                                                              sum2  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.      6553
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                        1402
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.        45311
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  130521
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                         992
#
#                                                                                                            sig  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.    ***
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                      ***
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.       ***
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  ***
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                      ***
#
#                                                                                                                                                                                                                                                                                                                      top1  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.    states netherlands greeks principles ages americans nations essays studies foundations sciences morals humeans stoics jews lectures meditations laws kantians descartes problems christians books dogmas logos
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                                                                                           vol. ed. pp. press. eds. trans op cambridge ma university ed no. nj philosophy q. chap abstract oxford journal logic p part paris eds vol
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.                                                                            was were had did thought said saw made came took became found knew used gave believed put meant argued seemed called began led held wrote
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.                                                                   god kant s a aristotle c t f descartes hume plato hegel sect heidegger husserl q john frege socrates university mr. professor quine russell e
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                                                                                                                                            i cf t q a ergo facie b vol al contra g l chap x hypothesi e fig de f kant man peter w o
#
#                                                                                                                                                                                                                                                                                   top2  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.    states jews ages americans works studies letters indians tales christians germans poems greeks essays notes men women arts europeans scots critics poets lives years romans
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                                                                   die pp. trans berlin ed ed. der op vol. das p. u. bd. goethe university univ. deutsche pp univ vol junker studien hans. cir h.
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.                                       was had were did made came wrote became said took saw found thought knew began went seemed gave used felt read called wanted brought sought
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.         god shakespeare english milton mr. new john england wordsworth king james coleridge sir chaucer christ la hamlet london spenser mrs. shelley lady johnson henry lord
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                                                                                i cf sir lord op lady me god friend man madam t mr. ed richard thou cf. james anna faith rohrscheid we pp you vol
#
#                                                                                                                                                                                                                               egs1  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.                                          "STATES are defined as" "Printed in the NETHERLANDS" "The GREEKS were good at it"
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                                                                      "of Descartes, VOL. Trans" "N. Beckman (ED. Amherst, MA" "Analysis, PP"
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.              "arbitrary subset WAS such that the axiom" "subsets that WERE not previously" "broader than HAD previously been"
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.  "beings such as GOD, who is not bound" "should have set KANT  s mind thinking" "Axiom P { ext (S)   S G is a partition"
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                                                "enemy... [I] f both divisions" "CF. In conjunction" "group case : [T] he proposed procedure"
#
#                                                                                                                                                                                                                                              egs2  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.    "the United STATES of the latter nineteenth" "possibilities that the JEWS and their conceptually" "of the Middle AGES) and transforms"
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                                                                       "allerwinzigste Punkt (DIE Ausgewanderten" "Harris, Cult, PP. Lang" "Movement, TRANS"
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.                       "the room there WAS little furniture" "These women then HAD to redefine themselves" "These gains WERE crucial in part"
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.                   "their duty to GOD, to their mother" "Montaigne, SHAKESPEARE, Napoleon, and" "called   Spoken ENGLISH  ), Drama, and"
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                                                                                               "I. Of Generic Worlds" "CF. At this point" "you, my dear SIR"
#
#                                                                                                            mdw_rank  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.           3
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                             8
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.             10
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.        11
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                            12
#
#                                                                                                            mdw1_rank  \
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.           98
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                             96
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.              95
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.         94
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                             93
#
#                                                                                                            mdw2_rank
# feat     feat_desc             result_desc
# NNPS     Proper noun, plural   Proper noun, plurals are 3.9x more common in Literature than Philosophy.            1
# list     ?                     ?s are 2.8x more common in Literature than Philosophy.                              3
# VBD      Verb, past tense      Verb, past tenses are 2.7x more common in Literature than Philosophy.               4
# NNP      Proper noun, singular Proper noun, singulars are 2.4x more common in Literature than Philosophy.          5
# vocative ?                     ?s are 2.3x more common in Literature than Philosophy.                              6

# %%
ids1 = df_meta.query('discipline == "Philosophy" & 1920<=year<1970').index.tolist()
ids2 = df_meta.query('discipline == "Philosophy" & 2025>=year>=1970').index.tolist()
odf = get_mdw_pos(ids1, ids2, 'Early Philosophy', 'Late Philosophy', feat_n=25, feat_min_count=1, incl_deprel=True, feat_n_egs=3,rename_cols=False).round(2).sort_values('mdw1_rank')
odf = odf[odf.sig=="***"]
odf.sort_values('mdw1_rank').head(10)
# Out:
#                                                                                                                                   fpk1  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          0.19
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          8.30
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          8.01
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.           7.92
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                  36.74
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  36.39
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  35.67
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.        0.72
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.      0.33
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                          0.63
#
#                                                                                                                                   fpk2  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          0.11
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          5.05
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          5.00
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.           5.04
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                  27.85
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  27.77
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  27.44
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.        0.55
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.      0.27
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                          0.52
#
#                                                                                                                                  odds_ratio  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               1.65
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               1.65
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               1.60
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                1.57
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                        1.32
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.        1.32
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.        1.31
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.             1.30
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.           1.24
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                               1.21
#
#                                                                                                                                   sum1  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                           257
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         11277
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         10877
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.          10759
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                  49890
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  49419
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  48441
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.         980
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.       449
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                           860
#
#                                                                                                                                    sum2  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                            483
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          21251
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                          21027
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.           21199
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                  117110
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  116770
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  115382
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.         2326
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.       1123
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                           2206
#
#                                                                                                                                  sig  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         ***
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         ***
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         ***
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.          ***
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                  ***
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  ***
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.  ***
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.       ***
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.     ***
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                         ***
#
#                                                                                                                                                                                                                                                                                                                                top1  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         have has made given determined intended prove determine regarded become having needed translatable developed excluded left refer essential conditioned taken understood said true reduced involves
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                                                " ' » '. ''
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                                                   " ' « ''
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                                                                    was were had did thought said made saw became found came seemed knew gave called wrote began took meant led went used held believed felt
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                                                                   have is one etc what less has not more false etc. other object time that philosophy action nature sense make good relations true knowledge others
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                                         and or but both nor either yet neither plus
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                 and or but nor yet rather as / plus
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                             most best least longest lest
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                                  whose
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                                                                         itself himself themselves pp. p no. herself another years today doubt times myself matter pp ourselves a.d ed. b week o'clock ix march b.c hemself
#
#                                                                                                                                                                                                                                                                                                                  top2  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         have give having has doing used stand exist explained entails achieve lies lead provides make become meaning differs require meant directing represented obeying intended considered
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                                   " ' » « ''
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                                   " ' « » ``
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                                                   was were had did said thought saw made took came argued believed used put knew gave meant found became called led wanted noted began caused
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                                                                 have etc b not one is what on has false others other properties theory relations al more true knowledge less time do etc. make belief
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                       and or but both either nor yet neither & plus n
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                             and or but rather / nor yet as & + plus n
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                   most best least foremost
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.                                                                                                                                                                                    whose
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                                                                                        itself themselves himself p herself pp. c x today way g time myself f another b doubt a y tomorrow years little e k u
#
#                                                                                                                                                                                                                                                             egs1  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                        "vectorial variable HAVE the same range" "in Chapter II HAS to be combined" "religion was MADE by Schlenimacher"
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                           "of   subject   as formulated by" "of existence   - the phrase is" "sunflowers are yellow » are intelligible"
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                         "the category of   subject   as formulated" "the previous   vulgar   measure" "sentences like « all sunflowers"
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                    "the sciences WAS pervasive of his" "reality as if they WERE pre-Kantian" "Dewey decided he HAD been wrong in trying"
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                                                 "and one should HAVE" "and that there IS a universal moral" "and not any ONE of them apart from"
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                           "experience, AND these categories" "yet developed OR done justice to" "should be, BUT it is in a more"
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                                       "an unvarying AND formal pattern" "vindication, OR who lay claim to" "BUT in his paper on"
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.                             "The MOST constructive part" "believed, can be BEST realized in a free" "we are at LEAST assured of this"
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.                                                                                               "so to speak, WHOSE extrinsic origin"
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                         "with the thing ITSELF" "analyses of Husserl HIMSELF (Logical Investigations" "conflicting dictates THEMSELVES seems requisite"
#
#                                                                                                                                                                                                                                                                 egs2  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                         "should already HAVE all future possibilities" "inference should GIVE some new information" "his account, HAVING sense impressions"
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                               "word   pure   when referring" "extension of   set   at t is sufficiently" "Connectives A, V, ». Parentheses"
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                      "understand the word   pure   when referring" "extension of   set   at t is sufficiently" "doo - be doo « now  , then"
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                             "arbitrary subset WAS such that the axiom" "subsets that WERE not previously" "broader than HAD previously been"
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                                                         "w, it will HAVE to grow between" "phenomenon and data, ETC" "of A and of B comes into view"
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.       "process of adding AND revising axioms" "to be unending OR, at least, to" "philosophic problems, BUT these are not peripheral"
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.                               "adopt lemma a AND remain a platonist" "arbitrary subset OR combination in" "BUT if our understanding"
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.                       "claim that the MOST substantial advances" "of course, BEST captured by Shaw" "that it is at LEAST conceivable for"
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.                                                                                          "the property) WHOSE elements are interpreted"
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                         "which the element ITSELF can enter" "just the objects THEMSELVES, rather than anything" "might be, Plato HIMSELF does not forsake"
#
#                                                                                                                                  mdw_rank  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               12
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               13
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                               14
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                15
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                        22
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.        24
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.        25
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.             26
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.           32
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                               37
#
#                                                                                                                                  mdw1_rank  \
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                 1
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                 2
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                 3
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                  4
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                          6
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.          7
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.          8
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.               9
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.            11
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                                12
#
#                                                                                                                                  mdw2_rank
# feat          feat_desc                result_desc
# csubj:pass    ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                98
# ''            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                97
# ``            ?                        ?s are 1.6x more common in Early Philosophy than Late Philosophy.                                96
# VBD           Verb, past tense         Verb, past tenses are 1.6x more common in Early Philosophy than Late Philosophy.                 95
# conj          Conjunct                 Conjuncts are 1.3x more common in Early Philosophy than Late Philosophy.                         93
# CC            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.         92
# cc            Coordinating conjunction Coordinating conjunctions are 1.3x more common in Early Philosophy than Late Philosophy.         91
# RBS           Adverb, superlative      Adverb, superlatives are 1.3x more common in Early Philosophy than Late Philosophy.              90
# WP$           Possessive wh-pronoun    Possessive wh-pronouns are 1.2x more common in Early Philosophy than Late Philosophy.            88
# nmod:unmarked ?                        ?s are 1.2x more common in Early Philosophy than Late Philosophy.                                87

# %%
odf.sort_values('mdw2_rank').head(10)
# Out:
#                                                                                                                              fpk1  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                        0.00
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                   0.06
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.  0.15
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.        2.52
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.         2.68
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   9.02
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                        0.12
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.   0.27
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                        0.56
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.        0.79
#
#                                                                                                                               fpk2  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                         0.03
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                    0.50
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.   0.43
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.         5.74
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.          6.01
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   19.18
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                         0.20
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.    0.43
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                         0.87
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.         1.23
#
#                                                                                                                              odds_ratio  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                              0.10
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                         0.12
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.        0.34
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.              0.44
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.               0.45
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.         0.47
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                              0.59
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.         0.64
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                              0.64
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.              0.65
#
#                                                                                                                               sum1  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                            4
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                      82
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.    200
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.         3425
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.          3641
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   12246
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                          157
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.     372
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                          759
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.         1076
#
#                                                                                                                               sum2  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                          121
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                    2087
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.   1800
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.        24126
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.         25277
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   80644
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                          824
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.    1803
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                         3667
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.         5157
#
#                                                                                                                              sig  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                        ***
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                   ***
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.  ***
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.        ***
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.         ***
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   ***
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                        ***
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.   ***
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                        ***
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.        ***
#
#                                                                                                                                                                                                                                                                                         top1  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                                                                                                                                                                                      $
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                                                                                                                                                        = / + -a ~ // +( => ..* /-
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.                                                                                            * - *) ~ -* ?> =' *( '( > *. ^ ;o -( v ;) =y '] { :d --* vs. t /? '..
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.                                                                                                                                                                    ) ]
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                                                                                                                                                             ( [ < -( a(
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   self sense material value world subject time living truth class space group con animal life law starting color century language state term art contingent prima
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                                      pp. op vol. journal chap paris no. pp vol university de notions philosophy ed series review trans. bk. logic iv. conduct mass ed. criticism brit.
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.                                                                                      ii iii c i pp pp. v b p. vii h.d iv op we x cf. d xi e vi ibid. g sec i. xii
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                                                     have used has made related make is say looks know seems do think what true possible does are came seem work makes feels seen arise
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.                                                                                a no b ii say so i like well yes iii c please v right viz d vol e viz. pp. oh vi alas p
#
#                                                                                                                                                                                                                                                                                                          top2  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                                                                                                                                                                                      £ $ \( £- }( <£ t(
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                                                                                                                                  = / + { ̄ \ -> \( => // ^ /- /( ~ ^( |= x *) := \- /a -+ /\ +( +/
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.                                                                                                                    * { | ~ -> · > ^ -* \ ** /? /. - >. := _ -< => ̄ = }. *( >( '(
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.                                                                                                                                                                                   ) ] >
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                                                                                                                                                                         ( [ < -( { a( t(
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   self truth order belief decision time level state set world sense language knowledge probability theory quantum con material university object type model subject color identity
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                                                                     vol. ed. press. eds. trans cambridge ma ed university pp. op nj q. abstract oxford p philosophy part department no. logic eds d t f
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.                                                                                                                       c ii i x a v iii b p ibid e op f pp. h cf + iv k j n t y g φ
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                                                                 have think is come has works know possible are used makes true take came work ought holds comes say understood use case thinks means do
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.                                                                                                                   so a ii i say b no iii like well yes p v viz o k c iv h y n vi w e oh
#
#                                                                                                                                                                                                                                          egs1  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                                                                                                      "suppose that $ is a num - valued"
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                                         "and let K =   A stranger wins" "resources and / or values distributed" "of C is : x + yw"
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.                    "a ground for * Mr. Schiller believes" "In the first of" "ourselves merely with *) Kleene, op"
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.                                                   "venture to call it) : for an inquiry" "rectilinear] triangle, I who"
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                    "definition   (Nature and Mind" "nature of a [rectilinear] triangle" "formal scale < f) for a by num"
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.   "experience of SELF - communion to" "reception of SENSE - data, and it" "intelligible the whole MATERIAL cosmos"
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                                                           "ch. Cp. L.U., PP. Cp. L.U., pp" "Hallowell, OP" "Recueils, VOL. SOVEREIGNTY"
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.           "in Meditation II to have discovered" "Logic, Part III, on   The Nature" "employees; (C) the percentage"
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                              "is that they HAVE meaning" "any kind has USED elements which" "defined that HAS the following characters"
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.                                    "modification is : (A) it enables us" "VOLUME L, NO" "anything, and (B) intuitively"
#
#                                                                                                                                                                                                                                      egs2  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                        "sublanguage L of $ £ with a notion of" "sublanguage L of $ £ with a notion" "A) then if \(B / A) is broken"
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                             "predicates, £ = { E, F,. Individual" "of sentences < / >v that are verifiable" "p (E) + p(F), lj"
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.                       "G < / >(*), we call physical" "Axiom P { ext (S)   S G" "to equal P(| E), in parallel"
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.                       "given!, V(t) must be an Rx for" "the human mind] answers to such" "G £ U Sf I > ext (A) G ¿"
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.         "powerset axiom : (Vu) (x) (Vy" "that   something [independent of" "of sentences < / >v that are verifiable"
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.          "prudence and SELF - interest (the" "every aGl, TRUTH assignment vff" "about first - ORDER standards"
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                                         "of Descartes, VOL. Trans" "N. Beckman (ED. Amherst, MA" "Cascadilla PRESS. Matushansky, O"
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.                  "d) iff a < C or (a = c and" "end of section II, however, I do" "choosing criteria (I) - (iv"
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                                 "decision to act can HAVE side - effects" "about how I THINK we should conceive" "is true iff C IS"
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.                                   "SO, we may ask" "raising here are (A) how the identity" "In (II), we also treat"
#
#                                                                                                                              mdw_rank  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                               4
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                          5
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.         7
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.               8
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                9
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.         10
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                              11
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.         16
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                              17
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.              18
#
#                                                                                                                              mdw1_rank  \
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                               95
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                          94
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.         92
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.               91
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                90
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.          89
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                               88
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.          87
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                               86
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.               85
#
#                                                                                                                              mdw2_rank
# feat        feat_desc               result_desc
# $           ?                       ?s are 9.8x more common in Late Philosophy than Early Philosophy.                                4
# SYM         Symbol                  Symbols are 8.2x more common in Late Philosophy than Early Philosophy.                           5
# NFP         Superfluous punctuation Superfluous punctuations are 2.9x more common in Late Philosophy than Early Philosophy.          7
# -RRB-       Right parenthesis       Right parenthesiss are 2.3x more common in Late Philosophy than Early Philosophy.                8
# -LRB-       Left parenthesis        Left parenthesiss are 2.2x more common in Late Philosophy than Early Philosophy.                 9
# compound    Compound word modifier  Compound word modifiers are 2.1x more common in Late Philosophy than Early Philosophy.          10
# list        ?                       ?s are 1.7x more common in Late Philosophy than Early Philosophy.                               11
# dep         Unclassified dependent  Unclassified dependents are 1.6x more common in Late Philosophy than Early Philosophy.          12
# advcl:relcl ?                       ?s are 1.6x more common in Late Philosophy than Early Philosophy.                               13
# discourse   Discourse element       Discourse elements are 1.5x more common in Late Philosophy than Early Philosophy.               14

# %%
ids1 = df_meta.query('discipline == "Literature" & 1920<=year<1970').index.tolist()
ids2 = df_meta.query('discipline == "Literature" & 2025>=year>=1970').index.tolist()
odf = get_mdw_pos(ids1, ids2, 'Early Literature', 'Late Literature', feat_n=25, feat_min_count=1, incl_deprel=True, feat_n_egs=3,rename_cols=False).round(2)
# odf[odf.sig=="***"]

# %%
odf.sort_values('mdw1_rank').head(10)
# Out:
#                                                                                                                              fpk1  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.          0.15
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                         0.12
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                         0.52
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                         0.64
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.              1.25
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.   0.14
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.         1.20
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.              0.37
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                         0.06
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.         19.59
#
#                                                                                                                              fpk2  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.          0.06
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                         0.05
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                         0.24
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                         0.33
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.              0.67
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.   0.08
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.         0.67
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.              0.22
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                         0.03
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.         13.44
#
#                                                                                                                             odds_ratio  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.               2.65
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                              2.30
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                              2.17
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                              1.94
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                   1.87
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.        1.79
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.              1.79
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                   1.68
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                              1.66
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.               1.46
#
#                                                                                                                              sum1  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.           125
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                          101
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                          435
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                          535
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.              1036
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.    115
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.          995
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.               303
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                           48
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.         16259
#
#                                                                                                                              sum2  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.           111
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                          103
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                          470
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                          648
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.              1299
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.    151
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.         1308
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.               423
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                           68
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.         26212
#
#                                                                                                                             sig  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.         ***
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                        ***
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                        ***
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                        ***
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.             ***
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.  ***
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.        ***
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.             ***
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                         **
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.         ***
#
#                                                                                                                                                                                                                                                                                                                             top1  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                                                                                                                 ii a vi i iii v viii xli xi vii xxxvi xxviii xxii xxxviii xxxvii xxxi xviii lviii xliii lxvi
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                        made preceded extension writing come interjected found allusion type contain prepared assigned provide indebted revivify indicates soldier listened comes carved led used superseded spelled derived
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                                                                                                  cf i sir op lady lord god madam rohrscheid you james vol lu j. dryden me cf. ed catherine rev. al patkul blake arnold thou
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                                                                                       die berlin der op das u. pp. bd. goethe vol. deutsche junker studien p. hans. ed. h. e. diinnhaupt goethes univ. geschichte g. r. vol
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                                                                                                                     no like oh o well yes nay ah um please alas ha iii ay viz ich ii iv amen xli ch vol ib op cf
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.                                                                                                                                                             - * | > ~ ;- z { ~. :) :: ; *s </ ^ *- ~~
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.                                                                                                                      no like so oh ii o well yes a nay ah um please iii sir alas ha viz ay ta ich i ch iv b
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                                                                                                              etc e.g. etc. i.e. pp. i.e e.g c. so cf. v. ed. cf , i. eng. ibid. str. mar p. then bd. g. ca. soc.
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                                                              time end general hu past wynnere night noon era drama indirectly popery others mar also god seven respectful city capacity acting corpus course existence flea
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.                                                                    was had were did made wrote came found became said thought took knew saw gave went used seemed began felt read 'd called appeared brought
#
#                                                                                                                                                                                                                                                                                                                                      top2  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                                                                                                                                                                                      ii a vi v iii i iv vii viii xi k
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                            have used drawn considered influenced one ahistorical natural refraining harvesting opening challenged ornaments had visit done acting determined pricks employed taking includes emerged printed gathers
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                                                                                            i sir lord cf me t friend mr. anna lydia god man richard daughter radlova thou ed scott aufidius trans susan hector joanna mutandis booth
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                                                                               trans ed ed. pp. university vol. p. pp univ univ. print reply cambridge rev. print. studies rights college york oxford vol princeton die blank history
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                                                                                                                          no yes like well oh say o alas please nay vol ah iv um yeah ex ich ii yea ing fol er aer tis hee
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.                                                                                                                                     * | - { [. > ^ *** /. >. ~ _ :: '( .t. _. -- -> :; x~?? :i.:: :::: ;. ?- z
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.                                                                                                                         no so yes well like oh say o ii a please alas nay vol um i right p. aer ah pp. iii iv yeah n
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                                                                                                               etc e.g. i.e. etc. pp. i.e , ed. e.g esp. eds. c. ca. cf nt i. so &c. ibid. v. asap henceforth viz. bk. wer
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                        particular all then instance england ourselves generations siren onward always institution universal modernist sequence margins feedback fiat doing other objects especially times things persuadable sassoon
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.                                                                           was had were did made came wrote became said took saw began thought found knew seemed went felt wanted used called read gave sought brought
#
#                                                                                                                                                                                                                                                  egs1  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                                                                               "Cressida, III, II" "Items : (A) The issue of" "VI"
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                        "play had already MADE use of the Standards" "poems are PRECEDED by two letters" "system was an EXTENSION of the worship"
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                                                                                     "CF. He is so unquestioning" "See also I" "you, my dear SIR"
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                                           "TODT, H., DIE deutsche Begegnung" "Engelke, Heinr. BERLIN" "SCHMIDT, K., DER Wandel des Naturgefuhls"
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                                                                          "NO, I ask how things" "seem dream - LIKE" "belief, yet, OH"
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.                                "A bird cursin  l" "descriptions of * American Notes" "so many years | As Day tells houres"
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.                                                      "NO, I ask how things" "No, LIKE a bank for love" "SO potent is her beauty"
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                                          "this state,   ETC" "under ESEA (E.G., the tying of" "the merchants, ETC., it is impossible"
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                                                                 "for the second TIME signs in blood" "everyone as an END" "fishermen in GENERAL"
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.                                   "It WAS not my intention" "After I HAD distinguished these" "These types WERE as common as the"
#
#                                                                                                                                                                                                                                                    egs2  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                                                                                         "II" "consciousness, (A) the other is" "VI"
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                        "does not always HAVE a singular verb" "it has been USED in English verse" "and consistently DRAWN, and their hierarchical"
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                                                                        "I. Of Generic Worlds" "to him,   SIR, I  ve lived three" "might say, LORD"
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                                                                                              "Movement, TRANS" "Bruce Fink, ED" "ed. Burchell, ED"
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                                                             "See Cohen, NO" "H.C. : YES, but it means" "sofa or the LIKE, as the event"
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.                                                       "X *" "la muerte, | la eternajuventud" "OF MORE - AND - LESS : LETTER"
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.                                                          "Pictorial Imagery, NO" "SO the political can" "H.C. : YES, but it means"
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                                             "CINEMATIC MUSICAL ETC" "the sequenced (E.G., comic strip" "the world (I.E., with the vita"
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                                                "violence and in PARTICULAR on assassination" "and above ALL out of reach of" "comments since THEN"
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.              "the room there WAS little furniture" "These women then HAD to redefine themselves" "These gains WERE crucial in part"
#
#                                                                                                                             mdw_rank  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                5
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                               6
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                               7
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                              10
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                   11
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.        12
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.              13
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                   14
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                              15
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.               17
#
#                                                                                                                             mdw1_rank  \
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                 1
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                                2
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                                3
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                                4
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                     5
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.          6
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.                7
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                     8
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                                9
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.                10
#
#                                                                                                                             mdw2_rank
# feat       feat_desc               result_desc
# LS         List item marker        List item markers are 2.6x more common in Early Literature than Late Literature.                98
# csubj:pass ?                       ?s are 2.3x more common in Early Literature than Late Literature.                               97
# vocative   ?                       ?s are 2.2x more common in Early Literature than Late Literature.                               96
# list       ?                       ?s are 1.9x more common in Early Literature than Late Literature.                               95
# UH         Interjection            Interjections are 1.9x more common in Early Literature than Late Literature.                    94
# NFP        Superfluous punctuation Superfluous punctuations are 1.8x more common in Early Literature than Late Literature.         93
# discourse  Discourse element       Discourse elements are 1.8x more common in Early Literature than Late Literature.               92
# FW         Foreign word            Foreign words are 1.7x more common in Early Literature than Late Literature.                    91
# orphan     ?                       ?s are 1.7x more common in Early Literature than Late Literature.                               90
# VBD        Verb, past tense        Verb, past tenses are 1.5x more common in Early Literature than Late Literature.                89

# %%
odf.sort_values('mdw2_rank').head(10)
# Out:
#                                                                                                                             fpk1  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                        0.00
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                        0.00
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                        0.00
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                        0.02
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.        2.36
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.         2.95
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                        0.41
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  11.93
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.    0.39
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                        0.95
#
#                                                                                                                             fpk2  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                        0.01
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                        0.01
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                        0.00
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                        0.05
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.        3.59
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.         4.06
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                        0.55
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  15.80
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.    0.50
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                        1.17
#
#                                                                                                                            odds_ratio  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                             0.14
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                             0.20
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                             0.47
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                             0.50
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.             0.66
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.              0.73
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                             0.74
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.        0.75
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.         0.78
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                             0.81
#
#                                                                                                                            sum1  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                          1
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                          1
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                          1
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                         19
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.       1961
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.        2447
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                        340
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  9898
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.    325
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                        785
#
#                                                                                                                             sum2  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                          17
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                          12
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                           5
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                          90
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.        7002
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.         7912
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                        1074
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  30812
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.     984
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                        2277
#
#                                                                                                                            sig  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                         *
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                        **
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.       ***
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.        ***
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                       ***
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  ***
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.   ***
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                       ***
#
#                                                                                                                                                                                                                                                                                                     top1  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                                                                                                                                                                                                 wel
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                                                                                                                                                                                                a.'.
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                                                                                                                                                                             geschichtsdrama herbert
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                                                                      raising die accuse answer exist accept revert call gloss describe seem dramatize divide fits emphasize define deny point clear
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.                                                                                                                                                                               ) ] >
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.                                                                                                                                                                          ( [ < { ...
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                                                      came become had made said has felt have found feels influenced makes achieved becomes is can love set leads used come are introduced holds led
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.  self century love prose half language stage london school living twenty a subject folk paradise manuscript country world line college title renaissance character verse light
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.                                                                                                                                                                           whose
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                                                                                                                                                                    both either neither whether that
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                              top2  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                                                 mid non reli
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                       http://muse.jhu.edu/), .maloryproject.com www.jstor.org. www.atanarjuat.com/production_diary/apak_interview.html. g.b.h. http://gallica.bnf.fr. http://gallica. http://www.louvre.fr/llv/oeuvres/detail_notice. donaldm. scytheless %t_streeter@uvmvax.uvm.edu http://www.randomhouse.com/catalog/display.pperl—isbn= books.google.com
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                                 michael jenny futuri raymond
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                                                                                                                                                                                      write make live see speak talk take seek making matters read relive do try attempt troubles memorize modernize conquer frustrating direct moving deserves identify know
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                                     ) ] > [.
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                                         ( [ <
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                                                                                                                                                                                                                     came makes made say work read became is becomes go transformed have seems had come appear become live works saw see end know begins took
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.                                                                                                                                                                     self century world class material art family language life living time reading post subject e love state gender war renaissance film university animal half writing
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                               whose whos
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                                                                                                                                                                                                                                                                                                                             both either neither whether that
#
#                                                                                                                                                                                                                                                      egs1  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                                                                                                                  "table, of those WEL known knights"
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                                                                                                                                                 "A."
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                                                           "PETERSEN, J., GESCHICHTSDRAMA u. Nationaler Mythos" "EASTER SERMONS By HERBERT H. UMBACH"
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                                             "protests that RAISING him by love and" "Flavian should DIE among the rare" "To ACCUSE Moore of writing"
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.                                       "regularly do), Mrs. Ward printed" "with [them], they were upon" "keep [him] > it close until"
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.                                  "press numbers (as Dodsley  s publications" "he lived with [them], they were" "tsjok, tsjuk < Germi"
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                       "whenever Sterne CAME to York, & when" "Anselmo have BECOME goatherd and shepherd" "me who never HAD a Child   in Shakespeare"
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.              "are not always SELF - consistent individuals" "an eighteenth CENTURY hand on the inner" "The LOVE - sick King is"
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.                                                                                       "poorer in talent WHOSE tone is purer and"
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                                    "In this volume BOTH the Britannia and" "peculiarities EITHER (hjoei for hjoed" "But if NEITHER the show nor the"
#
#                                                                                                                                                                                                                                                         egs2  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                       "promulgated in the MID -fifteenth century" "defences of the NON -foot - based alternating" "nor age nor RELI gion mattered when"
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                                          "Project Muse (HTTP://MUSE.JHU.EDU/), demonstrate" "http://www.MALORYPROJECT.COM" "available at WWW.JSTOR.ORG"
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                                                                                        "MICHAEL PERRAUDIN" "JENNY MEZCIEMS" "FUTURI SPES VIRTUTEM ALIT"
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                                               "and that to WRITE is to bare one" "make art and to MAKE art is to take" "To LIVE without a metaphysical"
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.                                  "in the story) from outer or discourse" "the village] takes pride" "Telemachus,   > the first chapter"
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.                      "of the content (time as represented" "in which it [the village] takes" "identical with the   < Atlantic mountains"
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                                                                  "that  s how it CAME out" "paradoxically MAKES the mind intelligible" "wise, who MADE"
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.                                      "did not present SELF - portraits on" "nineteenth - CENTURY Europe" "of the second WORLD War"
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.                                                      "any language, WHOSE life experience" "that a boyfriend WHOS disposed to have"
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                                   "suggested by BOTH poem and novel" "I can begin EITHER with the toes or" "fulfillment, then, NEITHER in reducing the"
#
#                                                                                                                            mdw_rank  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                              3
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                              4
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                              8
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                              9
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.             16
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.              20
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                             23
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.        24
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.         28
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                             32
#
#                                                                                                                            mdw1_rank  \
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                              96
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                              95
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                              94
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                              93
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.              92
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.               91
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                              90
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.         89
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.          88
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                              87
#
#                                                                                                                            mdw2_rank
# feat        feat_desc              result_desc
# AFX         ?                      ?s are 7.2x more common in Late Literature than Early Literature.                               3
# ADD         ?                      ?s are 5.1x more common in Late Literature than Early Literature.                               4
# GW          ?                      ?s are 2.1x more common in Late Literature than Early Literature.                               5
# csubj:outer ?                      ?s are 2.0x more common in Late Literature than Early Literature.                               6
# -RRB-       Right parenthesis      Right parenthesiss are 1.5x more common in Late Literature than Early Literature.               7
# -LRB-       Left parenthesis       Left parenthesiss are 1.4x more common in Late Literature than Early Literature.                8
# advcl:relcl ?                      ?s are 1.3x more common in Late Literature than Early Literature.                               9
# compound    Compound word modifier Compound word modifiers are 1.3x more common in Late Literature than Early Literature.         10
# WP$         Possessive wh-pronoun  Possessive wh-pronouns are 1.3x more common in Late Literature than Early Literature.          11
# cc:preconj  ?                      ?s are 1.2x more common in Late Literature than Early Literature.                              12

# %%
odf.mean(numeric_only=True)
# Out:
# fpk1             20.853125
# fpk2             20.853437
# odds_ratio        1.089792
# sum1          17307.906250
# sum2          40664.666667
# mdw_rank         50.500000
# mdw1_rank        48.500000
# mdw2_rank        50.500000
# dtype: float64
