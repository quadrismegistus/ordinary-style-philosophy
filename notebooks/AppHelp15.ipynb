# %%
import sys; sys.path.append('..')
from osp import *

# %%
groups = [
    ('The Journal of Philosophy', "journal in ['The Journal of Philosophy']"),
    ('PMLA', "journal in ['PMLA']")
]
comparisons = [tuple(groups)]
comparisons
# Out:
# [(('The Journal of Philosophy', "journal in ['The Journal of Philosophy']"),
#   ('PMLA', "journal in ['PMLA']"))]

# %%
df_preds, df_feats, d_models = get_preds_feats(comparisons,_force=True)
# Out:
# ## The Journal of Philosophy vs PMLA
# 100%|██████████| 10/10 [00:12<00:00,  1.21s/it]

# %%
df_preds
# Out:
#                           true_label pred_label  prob_PMLA  \
# id
# lit/462186__03                  PMLA       PMLA   0.998956
# lit/44015716__02                PMLA       PMLA   0.998159
# lit/25501669__01                PMLA       PMLA   0.999999
# lit/1261170__03                 PMLA       PMLA   0.723170
# lit/44015708__02                PMLA       PMLA   0.998333
# ...                              ...        ...        ...
# lit/27760277__03          Literature        NaN   0.656832
# lit/30031939__01          Literature        NaN   0.999057
# phil/10.2307/2953730__03  Philosophy        NaN   0.012145
# lit/468421__06            Literature        NaN   0.614559
# phil/10.2307/2185617__06  Philosophy        NaN   0.003679
#
#                           prob_The Journal of Philosophy  \
# id
# lit/462186__03                              1.044244e-03
# lit/44015716__02                            1.841418e-03
# lit/25501669__01                            9.055619e-07
# lit/1261170__03                             2.768299e-01
# lit/44015708__02                            1.666736e-03
# ...                                                  ...
# lit/27760277__03                            3.431679e-01
# lit/30031939__01                            9.433952e-04
# phil/10.2307/2953730__03                    9.878552e-01
# lit/468421__06                              3.854411e-01
# phil/10.2307/2185617__06                    9.963213e-01
#
#                                                 test_label  confidence  \
# id
# lit/462186__03            PMLA / The Journal of Philosophy    0.998956
# lit/44015716__02          PMLA / The Journal of Philosophy    0.998159
# lit/25501669__01          PMLA / The Journal of Philosophy    0.999999
# lit/1261170__03           PMLA / The Journal of Philosophy    0.723170
# lit/44015708__02          PMLA / The Journal of Philosophy    0.998333
# ...                                                    ...         ...
# lit/27760277__03          PMLA / The Journal of Philosophy         NaN
# lit/30031939__01          PMLA / The Journal of Philosophy         NaN
# phil/10.2307/2953730__03  PMLA / The Journal of Philosophy         NaN
# lit/468421__06            PMLA / The Journal of Philosophy         NaN
# phil/10.2307/2185617__06  PMLA / The Journal of Philosophy         NaN
#
#                           correct  accuracy  support  run predict_type  \
# id
# lit/462186__03                  1    0.9365     2000    0           cv
# lit/44015716__02                1    0.9365     2000    0           cv
# lit/25501669__01                1    0.9365     2000    0           cv
# lit/1261170__03                 1    0.9365     2000    0           cv
# lit/44015708__02                1    0.9365     2000    0           cv
# ...                           ...       ...      ...  ...          ...
# lit/27760277__03                0       NaN     2000    9       unseen
# lit/30031939__01                0       NaN     2000    9       unseen
# phil/10.2307/2953730__03        0       NaN     2000    9       unseen
# lit/468421__06                  0       NaN     2000    9       unseen
# phil/10.2307/2185617__06        0       NaN     2000    9       unseen
#
#                                                  comparison
# id
# lit/462186__03            The Journal of Philosophy vs PMLA
# lit/44015716__02          The Journal of Philosophy vs PMLA
# lit/25501669__01          The Journal of Philosophy vs PMLA
# lit/1261170__03           The Journal of Philosophy vs PMLA
# lit/44015708__02          The Journal of Philosophy vs PMLA
# ...                                                     ...
# lit/27760277__03          The Journal of Philosophy vs PMLA
# lit/30031939__01          The Journal of Philosophy vs PMLA
# phil/10.2307/2953730__03  The Journal of Philosophy vs PMLA
# lit/468421__06            The Journal of Philosophy vs PMLA
# phil/10.2307/2185617__06  The Journal of Philosophy vs PMLA
#
# [336660 rows x 12 columns]

# %%
def plot_preds(figdf, **labs):
    fig = (
        p9.ggplot(
            figdf,
            p9.aes(x='year', y='mean', color='discipline'),
        )
        + p9.geom_errorbar(p9.aes(ymin='mean-stderr', ymax='mean+stderr'), width=1, alpha=0.75)
        + p9.geom_point(p9.aes(y='mean',size='count',shape='predict_type'))
        + p9.facet_wrap('comparison')
        + p9.theme_minimal()
        + p9.scale_size_continuous(range=(.5, 5))
        + p9.scale_y_continuous(labels=lambda l: [f'{int(v)}%' for v in l])
        + p9.geom_smooth(method='loess', span=0.5, alpha=0.25, size=1)
        + p9.labs(**labs)
        + p9.theme(
            plot_background=p9.element_rect(fill='white'),
            plot_title=p9.element_text(ha='left',size=13),
            plot_subtitle=p9.element_text(ha='left',size=11),
        )
    )
    return fig

# %%
def plot_df_preds(df_preds, y_prob_col, **labs):
    # df = pd.DataFrame(get_text_metadata(id) for id in tqdm(df_preds.index))
    df = df_preds.copy()
    df['text_id'] = [x.split('__')[0] for x in df_preds.index]
    df = df.merge(get_corpus_metadata(), left_on='text_id', right_index=True)
    
    odf = get_avgs_df(odf,['comparison','discipline','year','decade','predict_type'],y='correct').reset_index()
    return odf
    

plot_df_preds(df_preds, 'y_prob')
# Out:
#                           prob_PMLA  prob_The Journal of Philosophy  support  \
# id
# lit/460318__03             0.999997                        0.000003     2000
# lit/1261104__01            0.991289                        0.008711     2000
# lit/463014__02             0.996287                        0.003713     2000
# lit/457736__01             0.538762                        0.461238     2000
# lit/459589__04             0.999461                        0.000539     2000
# ...                             ...                             ...      ...
# lit/27760277__03           0.666525                        0.333475     2000
# lit/30031939__01           0.976679                        0.023321     2000
# phil/10.2307/2953730__03   0.020719                        0.979281     2000
# lit/468421__06             0.454130                        0.545870     2000
# phil/10.2307/2185617__06   0.016252                        0.983748     2000
#
#                           run predict_type                         comparison  \
# id
# lit/460318__03              0           cv  The Journal of Philosophy vs PMLA
# lit/1261104__01             0           cv  The Journal of Philosophy vs PMLA
# lit/463014__02              0           cv  The Journal of Philosophy vs PMLA
# lit/457736__01              0           cv  The Journal of Philosophy vs PMLA
# lit/459589__04              0           cv  The Journal of Philosophy vs PMLA
# ...                       ...          ...                                ...
# lit/27760277__03            9       unseen  The Journal of Philosophy vs PMLA
# lit/30031939__01            9       unseen  The Journal of Philosophy vs PMLA
# phil/10.2307/2953730__03    9       unseen  The Journal of Philosophy vs PMLA
# lit/459589__04            1950-1975     C20        lC20     C20 Literature
# ...                             ...     ...         ...                ...
# lit/27760277__03          2000-2025     C21        eC21     C21 Literature
# lit/30031939__01          2000-2025     C21        eC21     C21 Literature
# phil/10.2307/2953730__03  1975-2000     C20        lC20     C20 Philosophy
# lit/468421__06            1975-2000     C20        lC20     C20 Literature
# phil/10.2307/2185617__06  1975-2000     C20        lC20     C20 Philosophy
#
#                          halfcentury_discipline     period_discipline  \
# id
# lit/460318__03                  lC20 Literature  1950-1975 Literature
# lit/1261104__01                 lC20 Literature  1950-1975 Literature
# lit/463014__02                  lC20 Literature  1975-2000 Literature
# lit/457736__01                  eC20 Literature  1925-1950 Literature
# lit/459589__04                  lC20 Literature  1950-1975 Literature
# ...                                         ...                   ...
# lit/27760277__03                eC21 Literature  2000-2025 Literature
# lit/30031939__01                eC21 Literature  2000-2025 Literature
# phil/10.2307/2953730__03        lC20 Philosophy  1975-2000 Philosophy
# lit/468421__06                  lC20 Literature  1975-2000 Literature
# phil/10.2307/2185617__06        lC20 Philosophy  1975-2000 Philosophy
#
#                           decade_discipline  \
# id
# lit/460318__03              1960 Literature
# lit/1261104__01             1960 Literature
# lit/463014__02              1990 Literature
# lit/457736__01              1930 Literature
# lit/459589__04              1950 Literature
# ...                                     ...
# lit/27760277__03            2000 Literature
# lit/30031939__01            2000 Literature
# phil/10.2307/2953730__03    1990 Philosophy
# lit/468421__06              1970 Literature
# phil/10.2307/2185617__06    1990 Philosophy
#
#                                                        century_journal  \
# id
# lit/460318__03                                                C20 PMLA
# lit/1261104__01                                               C20 PMLA
# lit/463014__02                                                C20 PMLA
# lit/457736__01                                                C20 PMLA
# lit/459589__04                                                C20 PMLA
# ...                                                                ...
# lit/27760277__03                              C21 New Literary History
# lit/30031939__01                                               C21 ELH
# phil/10.2307/2953730__03  C20 Philosophy and Phenomenological Research
# lit/468421__06                                C20 New Literary History
# phil/10.2307/2185617__06                  C20 The Philosophical Review
#
#                                                       journal_orig
# id
# lit/460318__03                                                PMLA
# lit/1261104__01                                               PMLA
# lit/463014__02                                                PMLA
# lit/457736__01                                                PMLA
# lit/459589__04                                                PMLA
# ...                                                            ...
# lit/27760277__03                              New Literary History
# lit/30031939__01                                               ELH
# phil/10.2307/2953730__03  Philosophy and Phenomenological Research
# lit/468421__06                                New Literary History
# phil/10.2307/2185617__06                  The Philosophical Review
#
# [336660 rows x 27 columns]

# %%
figdf = get_avgs_df(odf,['comparison','discipline','year','decade','predict_type'],y='correct').reset_index()
figdf['mean']*=100

fig = plot_preds(
    figdf, 
    title="Predicting philosophy syntactically", 
    y="Accuracy of discipline prediction (%)",
    subtitle="Accuracy scores by model training period",
    size='Number of samples',
    shape='Prediction type',
    color='Discipline',
)
fig.save('../figures/preds_by_comparison.png')
fig

# %%
comparisons = sorted(df_feats.comparison.unique())
comparisons
# Out:
# ['1900-1925 Philosophy vs 1900-1925 Literature',
#  '1925-1950 Philosophy vs 1925-1950 Literature',
#  '1950-1975 Philosophy vs 1950-1975 Literature',
#  '1975-2000 Philosophy vs 1975-2000 Literature',
#  '2000-2025 Philosophy vs 2000-2025 Literature']

# %%
o = []
for cmp in comparisons:
    df_cmp = df_feats[df_feats.comparison == cmp]
    g1,g2 = cmp.split(' vs ')
    period = int(cmp.split('-')[0])
    meancol1 = f'mean_{g1}'
    meancol2 = f'mean_{g2}'
    
    for i,row in df_cmp.iterrows():
        feat = row['feature']
        raw1 = float(row[meancol1])
        raw2 = float(row[meancol2])
        weight = row['weight']


        odx = {'feat': feat, 'feat_type': feat.split('_')[0], 'period': period, 'mean1': raw1, 'mean2': raw2, 'weight': weight, 'comparison': cmp, 'mean_diff': raw1 - raw2}
        o.append(odx)

odf = pd.DataFrame(o)
odf[odf.period==1900].sort_values('weight', ascending=False)
# Out:
#            feat feat_type  period     mean1     mean2    weight  \
# 61       pos_NN       pos    1900  0.202163 -0.792170  1.210699
# 29  deprel_nmod    deprel    1900  0.421042 -0.002823  0.975336
# 64      pos_NNS       pos    1900 -0.278908 -0.546365  0.768563
# 28  deprel_mark    deprel    1900 -0.123549 -0.795709  0.747265
# 48       pos_CC       pos    1900  0.604726  0.006938  0.719714
# ..          ...       ...     ...       ...       ...       ...
# 62      pos_NNP       pos    1900 -0.525119  1.141156 -0.801226
# 66      pos_POS       pos    1900 -0.563618  0.217228 -0.871326
# 98     ttr_mean       ttr    1900  0.317987  0.247548 -0.991623
# 9   deprel_case    deprel    1900  0.415585  0.248035 -1.019154
# 52       pos_FW       pos    1900 -0.180012  0.874235 -1.159358
#
#                                       comparison  mean_diff
# 61  1900-1925 Philosophy vs 1900-1925 Literature   0.994333
# 29  1900-1925 Philosophy vs 1900-1925 Literature   0.423864
# 64  1900-1925 Philosophy vs 1900-1925 Literature   0.267457
# 28  1900-1925 Philosophy vs 1900-1925 Literature   0.672160
# 48  1900-1925 Philosophy vs 1900-1925 Literature   0.597788
# ..                                           ...        ...
# 62  1900-1925 Philosophy vs 1900-1925 Literature  -1.666275
# 66  1900-1925 Philosophy vs 1900-1925 Literature  -0.780846
# 98  1900-1925 Philosophy vs 1900-1925 Literature   0.070439
# 9   1900-1925 Philosophy vs 1900-1925 Literature   0.167551
# 52  1900-1925 Philosophy vs 1900-1925 Literature  -1.054247
#
# [99 rows x 8 columns]

# %%
from scipy import stats

# Linear regression of weight by period for each feature
regression_results = []
by = 'weight'

for feat in odf['feat'].unique():
    df_feat = odf[odf['feat'] == feat].sort_values('period')
    
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(df_feat['period'], df_feat[by])
    vals = df_feat[by].values

    
    regression_results.append({
        'feat': feat,
        'feat_type': feat.split('_')[0],
        'slope': slope,
        'intercept': intercept,
        'r_squared': r_value**2,
        'p_value': p_value,
        'std_err': std_err,
        'weight': ' '.join(f'{v:.2f}' for v in df_feat['weight'].values),
        'mean_diff': ' '.join(f'{v:.2f}' for v in df_feat['mean_diff'].values),
        'mean1': ' '.join(f'{float(v):.2f}' for v in df_feat['mean1'].values),
        'mean2': ' '.join(f'{float(v):.2f}' for v in df_feat['mean2'].values),
    })

regression_df = pd.DataFrame(regression_results).sort_values('slope', ascending=False)
regression_df.head(20)
# Out:
#                 feat feat_type     slope  intercept  r_squared   p_value  \
# 4      deprel_advmod    deprel  0.018297 -35.094143   0.771249  0.050080
# 9        deprel_case    deprel  0.017242 -33.780755   0.972797  0.001920
# 12   deprel_compound    deprel  0.016988 -33.057924   0.582677  0.133195
# 52            pos_FW       pos  0.010970 -21.852393   0.596469  0.125869
# 8    deprel_aux:pass    deprel  0.010772 -20.873538   0.838605  0.028980
# 14       deprel_conj    deprel  0.010681 -21.197345   0.740384  0.061248
# 22  deprel_discourse    deprel  0.009931 -19.191571   0.680579  0.085556
# 36        deprel_obj    deprel  0.009125 -17.905296   0.405498  0.247953
# 89           sent_DC      sent  0.008782 -16.812415   0.932479  0.007603
# 73           pos_SYM       pos  0.008573 -16.829940   0.953575  0.004306
# 76            pos_VB       pos  0.008223 -15.997513   0.468964  0.202075
# 87           sent_C*      sent  0.007690 -14.723332   0.849664  0.025954
# 93           sent_Wd      sent  0.007255 -13.753340   0.917042  0.010405
# 62           pos_NNP       pos  0.007183 -14.658986   0.708870  0.073617
# 15        deprel_cop    deprel  0.006475 -12.042985   0.513957  0.172928
# 47           pos_AFX       pos  0.006000 -11.887488   0.807078  0.038291
# 35     deprel_nummod    deprel  0.005862 -11.516027   0.755874  0.055527
# 24       deprel_expl    deprel  0.005852 -11.582884   0.881251  0.018029
# 11      deprel_ccomp    deprel  0.005780 -10.870547   0.786464  0.044919
# 66           pos_POS       pos  0.005406 -11.033401   0.684001  0.084069
#
#      std_err                         weight                      mean_diff  \
# 4   0.005753     -0.12 -0.36 0.64 1.55 1.21       0.54 0.48 0.53 0.60 0.76
# 9   0.001665     -1.02 -0.72 0.02 0.29 0.63   0.17 -0.09 -0.57 -0.65 -0.83
# 12  0.008300     -0.62 -0.84 0.02 1.37 0.40    -0.32 -0.32 -0.08 0.30 0.11
# 52  0.005210   -1.16 -0.85 -0.21 0.28 -0.35  -1.05 -0.61 -0.47 -0.22 -0.36
# 8   0.002728     -0.31 -0.42 0.32 0.49 0.58       0.18 0.45 0.57 0.44 0.36
# 14  0.003652    -0.69 -0.99 -0.40 0.16 0.07   0.12 -0.02 -0.38 -0.79 -1.06
# 22  0.003928     -0.31 -0.37 0.48 0.65 0.42     -0.47 -0.45 0.05 0.29 0.32
# 36  0.006379    -0.11 -1.00 -0.20 0.44 0.31    -0.08 -0.27 -0.04 0.05 0.20
# 89  0.001364     -0.12 -0.01 0.41 0.62 0.66       0.64 0.57 0.84 0.74 0.88
# 73  0.001092    -0.45 -0.43 -0.11 0.07 0.36     -0.05 -0.03 0.00 0.19 0.31
# 76  0.005052     -0.77 0.39 -0.01 0.21 0.35       0.62 0.58 0.97 1.01 1.07
